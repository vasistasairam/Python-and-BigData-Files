# %% [markdown]
# <h1 id="tocheading">Table of Contents</h1>
# <div id="toc"></div>

# %%
# %%javascript
# $.getScript('https://kmahelona.github.io/ipython_notebook_goodies/ipython_notebook_toc.js')

# %% [markdown]
# # Weather Data

# %% [markdown]
# ## Import Packages and Data Loading

# %%
import pandas as pd
import numpy as np
from datetime import date
from datetime import datetime
import dateutil
from pandas import *
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
weather = pd.ExcelFile('C:\\Users\\HP\Desktop\\PHD Hackathon\\Data Science\\PhD_Train_Data\\WeatherDataNew.xlsx')
weather9 = pd.read_excel(weather, sheetname='2009')
weather10 = pd.read_excel(weather, sheetname='2010', na_values=[' ', '-'])
weather11 = pd.read_excel(weather, sheetname='2011', na_values=[' ', '-'])
weather12 = pd.read_excel(weather, sheetname='2012', na_values=[' ', '-'])
weather13 = pd.read_excel(weather, sheetname='2013', na_values=[' ', '-'])
weather14 = pd.read_excel(weather, sheetname='2014', na_values=[' ', '-'])
weather15 = pd.read_excel(weather, sheetname='2015', na_values=[' ', '-'])

# %%
df_list = [weather9, weather10, weather11, weather12, weather13, weather14, weather15]

weatherData = pd.concat(df_list)
weatherData.head()
# Out:
#    Year Month  Day  Temp high (°C)  Temp avg (°C)  Temp low (°C)  \
# 0  2009   Jan    1            -3.0           -6.0           -9.0
# 1  2009   Jan    2             1.0           -2.0           -5.0
# 2  2009   Jan    3             3.0            1.0           -2.0
# 3  2009   Jan    4             6.0            1.0           -4.0
# 4  2009   Jan    5             6.0            5.0            3.0
#
#    Dew Point high (°C)  Dew Point avg (°C)  Dew Point low (°C)  \
# 0                -16.0               -17.0               -19.0
# 1                 -3.0                -7.0               -17.0
# 2                 -5.0                -9.0               -13.0
# 3                -10.0               -12.0               -13.0
# 4                 -1.0                -5.0               -16.0
#
#    Humidity (%) high     ...       Sea Level Press. (hPa) avg  \
# 0               54.0     ...                           1023.0
# 1               78.0     ...                           1012.0
# 2               72.0     ...                           1015.0
# 3               55.0     ...                           1017.0
# 4               62.0     ...                           1014.0
#
#    Sea Level Press. (hPa) low  Visibility (km) high  Visibility (km) avg  \
# 0                      1015.0                  16.0                 16.0
# 1                      1007.0                  16.0                 13.0
# 2                      1008.0                  16.0                 16.0
# 3                      1015.0                  16.0                 16.0
# 4                      1013.0                  16.0                 16.0
#
#    Visibility (km) low  Wind (km/h) low  Wind (km/h) avg  Wind (km/h) high  \
# 0                 16.0               37               18                60
# 1                  2.0               27               10                48
# 2                 16.0               27               16                42
# 3                 16.0               32               12                40
# 4                 16.0               23               11                34
#
#   Precip. (mm) sum WeatherEvent
# 0                0          NaN
# 1                T         Snow
# 2                T          NaN
# 3                0          NaN
# 4                T          NaN
#
# [5 rows x 23 columns]

# %%
weatherData.shape
# Out:
# (2556, 23)

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Dropping Day Column

# %%
weatherData_noDay = weatherData.copy().drop('Day', axis = 1)
weatherData_noDay.shape
# Out:
# (2556, 22)

# %% [markdown]
# ### Changing Column Names

# %%
weatherData_noDay.columns = ['Year', 'Month', 'Temp high (°C)', 'Temp avg (°C)', 'Temp low (°C)',
                        'Dew Point high (°C)', 'Dew Point avg (°C)', 'Dew Point low (°C)',
                       'Humidity_high', 'Humidity_avg', 'Humidity_low','Sea Level Press high', 'Sea Level Press avg',
                       'Sea Level Press low', 'Visibility (km) high','Visibility (km) avg', 'Visibility (km) low', 'Wind (km/h) low',
                       'Wind (km/h) avg', 'Wind (km/h) high', 'Precip (mm) sum','WeatherEvent']

# %% [markdown]
# ### Change Month Names To Numbers

# %%
vals_to_replace = {'Jan':'1','Feb':'2','Mar':'3','Apr':'4','May':'5','Jun':'6','Jul':'7','Aug':'8','Sep':'9','Oct':'10','Nov':'11','Dec':'12'}
weatherData_noDay['Month'] = weatherData_noDay['Month'].apply(lambda x: vals_to_replace[x])

# %% [markdown]
# ### Replace T value With 0.01 in Precip (mm) sum Column
# - In liquid Precipitation, anything less than 0.01 inch of rain is reported as a trace of rain

# %%
print("Nulls In (Precip (mm) sum) :", weatherData_noDay['Precip (mm) sum'].isnull().sum())
weatherData_noDay['Precip (mm) sum'] =   weatherData_noDay['Precip (mm) sum'].apply(lambda x: 0.01 if x == 'T' else x)  
weatherData_noDay['Precip (mm) sum'].isnull().sum()
# Out:
# Nulls In (Precip (mm) sum) : 1
# 1

# %% [markdown]
# ### Convert Dtypes Of Columns

# %%
weatherData_noDay.dtypes
# Out:
# Year                      int64
# Month                    object
# Temp high (°C)          float64
# Temp avg (°C)           float64
# Temp low (°C)           float64
# Dew Point high (°C)     float64
# Dew Point avg (°C)      float64
# Dew Point low (°C)      float64
# Humidity_high           float64
# Humidity_avg            float64
# Humidity_low            float64
# Sea Level Press high    float64
# Sea Level Press avg     float64
# Sea Level Press low     float64
# Visibility (km) high    float64
# Visibility (km) avg     float64
# Visibility (km) low     float64
# Wind (km/h) low          object
# Wind (km/h) avg          object
# Wind (km/h) high         object
# Precip (mm) sum         float64
# WeatherEvent             object
# dtype: object

# %%
weatherData_noDay.iloc[:, 2:-1] = weatherData_noDay.iloc[:, 2:-1].apply(pd.to_numeric, errors = 'coerce')
weatherData_noDay.dtypes
# Out:
# Year                      int64
# Month                    object
# Temp high (°C)          float64
# Temp avg (°C)           float64
# Temp low (°C)           float64
# Dew Point high (°C)     float64
# Dew Point avg (°C)      float64
# Dew Point low (°C)      float64
# Humidity_high           float64
# Humidity_avg            float64
# Humidity_low            float64
# Sea Level Press high    float64
# Sea Level Press avg     float64
# Sea Level Press low     float64
# Visibility (km) high    float64
# Visibility (km) avg     float64
# Visibility (km) low     float64
# Wind (km/h) low         float64
# Wind (km/h) avg         float64
# Wind (km/h) high        float64
# Precip (mm) sum         float64
# WeatherEvent             object
# dtype: object

# %% [markdown]
# ### Filling Missing Values

# %%
weatherData_noDay.isnull().sum()/len(weatherData_noDay)*100
# Out:
# Year                     0.000000
# Month                    0.000000
# Temp high (°C)           0.078247
# Temp avg (°C)            0.078247
# Temp low (°C)            0.078247
# Dew Point high (°C)      0.078247
# Dew Point avg (°C)       0.078247
# Dew Point low (°C)       0.078247
# Humidity_high            0.078247
# Humidity_avg             0.078247
# Humidity_low             0.078247
# Sea Level Press high     0.547731
# Sea Level Press avg      0.547731
# Sea Level Press low      0.547731
# Visibility (km) high     0.899844
# Visibility (km) avg      0.899844
# Visibility (km) low      0.899844
# Wind (km/h) low          0.586854
# Wind (km/h) avg          0.586854
# Wind (km/h) high         1.799687
# Precip (mm) sum          0.039124
# WeatherEvent            65.023474
# dtype: float64

# %%
weatherData_noDay.iloc[:, 2:-1] = weatherData_noDay.iloc[:, 2:-1].apply(lambda x: x.fillna(x.mean()))
weatherData_noDay.loc[:, 'WeatherEvent'] = weatherData_noDay.loc[:, 'WeatherEvent'].fillna('Other')

# %%
weatherData_noDay.isnull().sum()
# Out:
# Year                    0
# Month                   0
# Temp high (°C)          0
# Temp avg (°C)           0
# Temp low (°C)           0
# Dew Point high (°C)     0
# Dew Point avg (°C)      0
# Dew Point low (°C)      0
# Humidity_high           0
# Humidity_avg            0
# Humidity_low            0
# Sea Level Press high    0
# Sea Level Press avg     0
# Sea Level Press low     0
# Visibility (km) high    0
# Visibility (km) avg     0
# Visibility (km) low     0
# Wind (km/h) low         0
# Wind (km/h) avg         0
# Wind (km/h) high        0
# Precip (mm) sum         0
# WeatherEvent            0
# dtype: int64

# %% [markdown]
# ### Correlation Between Weather Features

# %%
corplot = weatherData_noDay.iloc[:, 2:-1].corr()
corplot.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row0_col0 {
#             background-color:  #023858;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row0_col1 {
#             background-color:  #02395a;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row0_col2 {
#             background-color:  #023f64;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row0_col3 {
#             background-color:  #034c78;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row0_col4 {
#             background-color:  #034c78;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row0_col5 {
#             background-color:  #034f7d;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row0_col6 {
#             background-color:  #509ac6;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row0_col7 {
#             background-color:  #6ba5cd;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row0_col8 {
#             background-color:  #96b6d7;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row0_col9 {
#             background-color:  #f8f1f8;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row0_col10 {
#             background-color:  #eee8f3;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row0_col11 {
#             background-color:  #cdd0e5;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row0_col12 {
#             background-color:  #dcdaeb;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row0_col13 {
#             background-color:  #91b5d6;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row0_col14 {
#             background-color:  #97b7d7;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row0_col15 {
#             background-color:  #fef6fa;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row0_col16 {
#             background-color:  #fff7fb;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row0_col17 {
#             background-color:  #f7f0f7;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row0_col18 {
#             background-color:  #a4bcda;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row1_col0 {
#             background-color:  #02395a;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row1_col1 {
#             background-color:  #023858;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row1_col2 {
#             background-color:  #023a5b;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row1_col3 {
#             background-color:  #034871;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row1_col4 {
#             background-color:  #03466e;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row1_col5 {
#             background-color:  #034871;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row1_col6 {
#             background-color:  #4697c4;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row1_col7 {
#             background-color:  #5a9ec9;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row1_col8 {
#             background-color:  #84b0d3;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row1_col9 {
#             background-color:  #faf3f9;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row1_col10 {
#             background-color:  #efe9f3;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row1_col11 {
#             background-color:  #d0d1e6;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row1_col12 {
#             background-color:  #dfddec;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row1_col13 {
#             background-color:  #99b8d8;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row1_col14 {
#             background-color:  #9fbad9;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row1_col15 {
#             background-color:  #fff7fb;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row1_col16 {
#             background-color:  #fff7fb;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row1_col17 {
#             background-color:  #f8f1f8;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row1_col18 {
#             background-color:  #9fbad9;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row2_col0 {
#             background-color:  #023f64;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row2_col1 {
#             background-color:  #023a5b;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row2_col2 {
#             background-color:  #023858;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row2_col3 {
#             background-color:  #03476f;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row2_col4 {
#             background-color:  #034369;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row2_col5 {
#             background-color:  #03446a;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row2_col6 {
#             background-color:  #3b92c1;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row2_col7 {
#             background-color:  #4897c4;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row2_col8 {
#             background-color:  #71a8ce;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row2_col9 {
#             background-color:  #fcf4fa;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row2_col10 {
#             background-color:  #f0eaf4;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row2_col11 {
#             background-color:  #d1d2e6;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row2_col12 {
#             background-color:  #e1dfed;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row2_col13 {
#             background-color:  #a1bbda;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row2_col14 {
#             background-color:  #a5bddb;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row2_col15 {
#             background-color:  #fff7fb;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row2_col16 {
#             background-color:  #fef6fb;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row2_col17 {
#             background-color:  #f9f2f8;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row2_col18 {
#             background-color:  #97b7d7;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row3_col0 {
#             background-color:  #034b76;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row3_col1 {
#             background-color:  #03476f;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row3_col2 {
#             background-color:  #03466e;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row3_col3 {
#             background-color:  #023858;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row3_col4 {
#             background-color:  #023b5d;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row3_col5 {
#             background-color:  #03456c;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row3_col6 {
#             background-color:  #056dac;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row3_col7 {
#             background-color:  #0d75b3;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row3_col8 {
#             background-color:  #3790c0;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row3_col9 {
#             background-color:  #fef6fb;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row3_col10 {
#             background-color:  #faf2f8;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row3_col11 {
#             background-color:  #e5e1ef;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row3_col12 {
#             background-color:  #e8e4f0;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row3_col13 {
#             background-color:  #cccfe5;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row3_col14 {
#             background-color:  #d2d3e7;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row3_col15 {
#             background-color:  #f8f1f8;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row3_col16 {
#             background-color:  #faf3f9;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row3_col17 {
#             background-color:  #f1ebf5;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc15b4e90c00row3_col18 {
#             background-color:  #76aad0;
#         }    #T_db00d45c_2bc8_11e9_8a76_fc1

# %%
weatherData_final = weatherData_noDay.copy()
len(weatherData_final.columns)
# Out:
# 22

# %%
weatherData_final.isnull().sum()
# Out:
# Year                    0
# Month                   0
# Temp high (°C)          0
# Temp avg (°C)           0
# Temp low (°C)           0
# Dew Point high (°C)     0
# Dew Point avg (°C)      0
# Dew Point low (°C)      0
# Humidity_high           0
# Humidity_avg            0
# Humidity_low            0
# Sea Level Press high    0
# Sea Level Press avg     0
# Sea Level Press low     0
# Visibility (km) high    0
# Visibility (km) avg     0
# Visibility (km) low     0
# Wind (km/h) low         0
# Wind (km/h) avg         0
# Wind (km/h) high        0
# Precip (mm) sum         0
# WeatherEvent            0
# dtype: int64

# %%
c = ['Temp high (°C)', 'Temp avg (°C)', 'Temp low (°C)',
       'Dew Point high (°C)', 'Dew Point avg (°C)', 'Dew Point low (°C)',
       'Humidity_high', 'Humidity_avg', 'Humidity_low', 'Sea Level Press high',
       'Sea Level Press avg', 'Sea Level Press low', 'Visibility (km) high',
       'Visibility (km) avg', 'Visibility (km) low', 'Wind (km/h) low',
       'Wind (km/h) avg', 'Wind (km/h) high', 'Precip (mm) sum']

# %%
weatherData_noDay.head()
# Out:
#    Year Month  Temp high (°C)  Temp avg (°C)  Temp low (°C)  \
# 0  2009     1            -3.0           -6.0           -9.0
# 1  2009     1             1.0           -2.0           -5.0
# 2  2009     1             3.0            1.0           -2.0
# 3  2009     1             6.0            1.0           -4.0
# 4  2009     1             6.0            5.0            3.0
#
#    Dew Point high (°C)  Dew Point avg (°C)  Dew Point low (°C)  Humidity_high  \
# 0                -16.0               -17.0               -19.0           54.0
# 1                 -3.0                -7.0               -17.0           78.0
# 2                 -5.0                -9.0               -13.0           72.0
# 3                -10.0               -12.0               -13.0           55.0
# 4                 -1.0                -5.0               -16.0           62.0
#
#    Humidity_avg      ...       Sea Level Press avg  Sea Level Press low  \
# 0          43.0      ...                    1023.0               1015.0
# 1          57.0      ...                    1012.0               1007.0
# 2          54.0      ...                    1015.0               1008.0
# 3          42.0      ...                    1017.0               1015.0
# 4          48.0      ...                    1014.0               1013.0
#
#    Visibility (km) high  Visibility (km) avg  Visibility (km) low  \
# 0                  16.0                 16.0                 16.0
# 1                  16.0                 13.0                  2.0
# 2                  16.0                 16.0                 16.0
# 3                  16.0                 16.0                 16.0
# 4                  16.0                 16.0                 16.0
#
#    Wind (km/h) low  Wind (km/h) avg  Wind (km/h) high  Precip (mm) sum  \
# 0             37.0             18.0              60.0             0.00
# 1             27.0             10.0              48.0             0.01
# 2             27.0             16.0              42.0             0.01
# 3             32.0             12.0              40.0             0.00
# 4             23.0             11.0              34.0             0.01
#
#    WeatherEvent
# 0         Other
# 1          Snow
# 2         Other
# 3         Other
# 4         Other
#
# [5 rows x 22 columns]

# %%
weatherEvent_pivot = pivot_table(data = weatherData_noDay, columns=['WeatherEvent'], index = ['Year', 'Month'], 
                                fill_value=1)

# %%
weatherEvent_pivot.head()
# Out:
#              Dew Point avg (°C)                                          \
# WeatherEvent                Fog Fog , Rain Fog , Rain , Snow Fog , Snow
# Year Month
# 2009 1                        1        1.0              -4.0       -3.5
#      10                       1       18.0               1.0        1.0
#      11                       1        1.0               1.0        1.0
#      12                       1        1.0               1.0       -8.0
#      2                        1        1.0               1.0       -2.0
#
#                                                                  \
# WeatherEvent      Other      Rain Rain , Snow Snow Thunderstorm
# Year Month
# 2009 1       -11.904762 -5.000000         1.0 -9.0            1
#      10        5.176471  8.615385         1.0  1.0            1
#      11        2.900000  6.700000         1.0  1.0            1
#      12       -7.800000  5.000000         2.5  1.0            1
#      2        -8.636364  3.500000        -1.0  1.0            1
#
#              Dew Point high (°C)     ...      Wind (km/h) high  \
# WeatherEvent                 Fog     ...          Thunderstorm
# Year Month                           ...
# 2009 1                       1.0     ...                     1
#      10                      1.0     ...                     1
#      11                      1.0     ...                     1
#      12                      1.0     ...                     1
#      2                       1.0     ...                     1
#
#              Wind (km/h) low                                          \
# WeatherEvent             Fog Fog , Rain Fog , Rain , Snow Fog , Snow
# Year Month
# 2009 1                     1        1.0              30.0  16.500000
#      10                    1       16.0               1.0   1.000000
#      11                    1        1.0               1.0   1.000000
#      12                    1        1.0               1.0  29.666667
#      2                     1        1.0               1.0  26.000000
#
#
# WeatherEvent      Other       Rain Rain , Snow       Snow Thunderstorm
# Year Month
# 2009 1        27.238095  31.000000         1.0  26.333333            1
#      10       20.352941  28.230769         1.0   1.000000            1
#      11       25.000000  27.600000         1.0   1.000000            1
#      12       28.450000  28.333333        29.0   1.000000            1
#      2        27.545455  30.750000        27.0   1.000000            1
#
# [5 rows x 171 columns]

# %%
weatherEvent_pivot.columns = [i[0]+"_"+i[1] for i in weatherEvent_pivot.columns]
weatherEvent_pivot.head()

# %%
weatherEvent_pivot.isnull().sum()/len(weatherEvent_pivot)*100
# Out:
# Dew Point avg (°C)_Fog                   86.904762
# Dew Point avg (°C)_Fog , Rain            30.952381
# Dew Point avg (°C)_Fog , Rain , Snow     83.333333
# Dew Point avg (°C)_Fog , Snow            77.380952
# Dew Point avg (°C)_Other                  0.000000
# Dew Point avg (°C)_Rain                   2.380952
# Dew Point avg (°C)_Rain , Snow           76.190476
# Dew Point avg (°C)_Snow                  73.809524
# Dew Point avg (°C)_Thunderstorm          98.809524
# Dew Point high (°C)_Fog                  86.904762
# Dew Point high (°C)_Fog , Rain           30.952381
# Dew Point high (°C)_Fog , Rain , Snow    83.333333
# Dew Point high (°C)_Fog , Snow           77.380952
# Dew Point high (°C)_Other                 0.000000
# Dew Point high (°C)_Rain                  2.380952
# Dew Point high (°C)_Rain , Snow          76.190476
# Dew Point high (°C)_Snow                 73.809524
# Dew Point high (°C)_Thunderstorm         98.809524
# Dew Point low (°C)_Fog                   86.904762
# Dew Point low (°C)_Fog , Rain            30.952381
# Dew Point low (°C)_Fog , Rain , Snow     83.333333
# Dew Point low (°C)_Fog , Snow            77.380952
# Dew Point low (°C)_Other                  0.000000
# Dew Point low (°C)_Rain                   2.380952
# Dew Point low (°C)_Rain , Snow           76.190476
# Dew Point low (°C)_Snow                  73.809524
# Dew Point low (°C)_Thunderstorm          98.809524
# Humidity_avg_Fog                         86.904762
# Humidity_avg_Fog , Rain                  30.952381
# Humidity_avg_Fog , Rain , Snow           83.333333
#                                            ...
# Visibility (km) low_Rain , Snow          76.190476
# Visibility (km) low_Snow                 73.809524
# Visibility (km) low_Thunderstorm         98.809524
# Wind (km/h) avg_Fog                      86.904762
# Wind (km/h) avg_Fog , Rain               30.952381
# Wind (km/h) avg_Fog , Rain , Snow        83.333333
# Wind (km/h) avg_Fog , Snow               77.380952
# Wind (km/h) avg_Other                     0.000000
# Wind (km/h) avg_Rain                      2.380952
# Wind (km/h) avg_Rain , Snow              76.190476
# Wind (km/h) avg_Snow                     73.809524
# Wind (km/h) avg_Thunderstorm             98.809524
# Wind (km/h) high_Fog                     86.904762
# Wind (km/h) high_Fog , Rain              30.952381
# Wind (km/h) high_Fog , Rain , Snow       83.333333
# Wind (km/h) high_Fog , Snow              77.380952
# Wind (km/h) high_Other                    0.000000
# Wind (km/h) high_Rain                     2.380952
# Wind (km/h) high_Rain , Snow             76.190476
# Wind (km/h) high_Snow                    73.809524
# Wind (km/h) high_Thunderstorm            98.809524
# Wind (km/h) low_Fog                      86.904762
# Wind (km/h) low_Fog , Rain               30.952381
# Wind (km/h) low_Fog , Rain , Snow        83.333333
# Wind (km/h) low_Fog , Snow               77.380952
# Wind (km/h) low_Other                     0.000000
# Wind (km/h) low_Rain                      2.380952
# Wind (km/h) low_Rain , Snow              76.190476
# Wind (km/h) low_Snow                     73.809524
# Wind (km/h) low_Thunderstorm             98.809524
# Length: 171, dtype: float64

# %%
weatherEvent_pivot.shape
# Out:
# (84, 171)

# %%
weatherData_noDay.WeatherEvent.value_counts()
# Out:
# Other                1662
# Rain                  600
# Fog , Rain            139
# Snow                   62
# Fog , Snow             36
# Rain , Snow            24
# Fog , Rain , Snow      20
# Fog                    12
# Thunderstorm            1
# Name: WeatherEvent, dtype: int64

# %%
replace_values = {'Other':0, 'Rain':1, 'Fog , Rain':2, 'Snow':3, 'Fog , Snow':4,  
                  'Rain , Snow':5, 'Fog , Rain , Snow':6, 'Fog':7, 'Thunderstorm':8}
weatherData_noDay['WeatherEvent_Num'] = weatherData_noDay['WeatherEvent'].apply(lambda x: replace_values[x])

# %%
weatherData_noDay.WeatherEvent_Num.value_counts()
# Out:
# 0    1662
# 1     600
# 2     139
# 3      62
# 4      36
# 5      24
# 6      20
# 7      12
# 8       1
# Name: WeatherEvent_Num, dtype: int64

# %%
weatherEventDf = pd.DataFrame()
weatherEventDf['Year'] = weatherData_noDay['Year']
weatherEventDf['Month'] = weatherData_noDay['Month']
weatherEventDf['WeatherEvent_Num'] = weatherData_noDay['WeatherEvent_Num']

weatherEventDf = weatherEventDf.groupby(['Year', 'Month']).agg('count').reset_index()
weatherEventDf.head()
# Out:
#    Year Month  WeatherEvent_Num
# 0  2009     1                31
# 1  2009    10                31
# 2  2009    11                30
# 3  2009    12                31
# 4  2009     2                28

# %% [markdown]
# ## Extracting New Features From Weather Data

# %%
col_list = ['Year', 'Month', 'Temp high (°C)', 'Temp avg (°C)', 'Temp low (°C)','Dew Point high (°C)', 'Dew Point avg (°C)', 
            'Dew Point low (°C)','Humidity_high', 'Humidity_avg', 'Humidity_low', 'Sea Level Press high','Sea Level Press avg',
            'Sea Level Press low', 'Visibility (km) high','Visibility (km) avg', 'Visibility (km) low', 'Wind (km/h) low',
            'Wind (km/h) avg', 'Wind (km/h) high', 'Precip (mm) sum','WeatherEvent']

# %%
features = {col_list[2]:['min','max','mean','var'],col_list[3]:['min','max','mean','var'],col_list[4]:['min','max','mean','var'],
           col_list[5]:['min','max','mean','var'], col_list[6]:['min','max','mean','var'], col_list[7]:['min','max','mean','var'],
           col_list[8]:['min','max','mean','var'], col_list[9]:['min','max','mean','var'], col_list[10]:['min','max','mean','var'],
col_list[11]:['min','max','mean','var'], col_list[12]:['min','max','mean','var'], col_list[13]:['min','max','mean','var'],
col_list[14]:['min','max','mean','var'], col_list[15]:['min','max','mean','var'], col_list[16]:['min','max','mean','var'],
col_list[17]:['min','max','mean','var'], col_list[18]:['min','max','mean','var'], col_list[19]:['min','max','mean','var']}

weather_features = weatherData_final.groupby(['Year','Month']).agg(features).reset_index()

# %%
weather_features.tail(5)
# Out:
#     Year Month Temp high (°C)                             Temp avg (°C)        \
#                           min   max       mean        var           min   max
# 79  2015     5           17.0  31.0  25.677419  16.159140          13.0  26.0
# 80  2015     6           13.0  32.0  25.800000  25.337931          12.0  28.0
# 81  2015     7           24.0  36.0  29.967742   7.565591          22.0  31.0
# 82  2015     8           27.0  35.0  30.516129   3.991398          23.0  31.0
# 83  2015     9           22.0  36.0  28.133333  14.050575          18.0  31.0
#
#                             ...     Wind (km/h) low             \
#          mean        var    ...                mean        var
# 79  20.483871  13.191398    ...           21.129032  17.582796
# 80  21.866667  17.636782    ...           21.100000  20.162069
# 81  26.129032   5.716129    ...           18.000000  19.000000
# 82  26.322581   3.625806    ...           18.548387  21.522581
# 83  23.700000  10.975862    ...           19.433333  24.805747
#
#    Wind (km/h) avg                            Wind (km/h) high        \
#                min   max      mean        var              min   max
# 79             3.0  12.0  6.806452   5.161290             18.0  47.0
# 80             4.0  17.0  7.533333   6.533333             21.0  47.0
# 81             2.0   9.0  5.483871   3.324731             19.0  50.0
# 82             3.0   9.0  5.903226   2.756989             23.0  58.0
# 83             2.0  13.0  7.033333  11.343678             18.0  43.0
#
#
#          mean        var
# 79  34.225806  50.913978
# 80  33.800000  46.441379
# 81  30.032258  48.298925
# 82  30.451613  48.189247
# 83  30.166667  51.247126
#
# [5 rows x 74 columns]

# %%
weather_features.isnull().sum()
# Out:
# Year                          0
# Month                         0
# Temp high (°C)        min     0
#                       max     0
#                       mean    0
#                       var     0
# Temp avg (°C)         min     0
#                       max     0
#                       mean    0
#                       var     0
# Temp low (°C)         min     0
#                       max     0
#                       mean    0
#                       var     0
# Dew Point high (°C)   min     0
#                       max     0
#                       mean    0
#                       var     0
# Dew Point avg (°C)    min     0
#                       max     0
#                       mean    0
#                       var     0
# Dew Point low (°C)    min     0
#                       max     0
#                       mean    0
#                       var     0
# Humidity_high         min     0
#                       max     0
#                       mean    0
#                       var     0
#                              ..
# Sea Level Press avg   mean    0
#                       var     0
# Sea Level Press low   min     0
#                       max     0
#                       mean    0
#                       var     0
# Visibility (km) high  min     0
#                       max     0
#                       mean    0
#                       var     0
# Visibility (km) avg   min     0
#                       max     0
#                       mean    0
#                       var     0
# Visibility (km) low   min     0
#                       max     0
#                       mean    0
#                       var     0
# Wind (km/h) low       min     0
#                       max     0
#                       mean    0
#                       var     0
# Wind (km/h) avg       min     0
#                       max     0
#                       mean    0
#                       var     0
# Wind (km/h) high      min     0
#                       max     0
#                       mean    0
#                       var     0
# Length: 74, dtype: int64

# %%
weather_features.columns = [x[0]+x[1] for x in weather_features.columns]
weather_features.head()
# Out:
#    Year Month  Temp high (°C)min  Temp high (°C)max  Temp high (°C)mean  \
# 0  2009     1               -9.0                8.0            0.741935
# 1  2009    10                7.0               23.0           16.258065
# 2  2009    11               10.0               21.0           13.733333
# 3  2009    12               -2.0               19.0            5.451613
# 4  2009     2               -6.0               18.0            6.964286
#
#    Temp high (°C)var  Temp avg (°C)min  Temp avg (°C)max  Temp avg (°C)mean  \
# 0          16.664516             -11.0               5.0          -2.096774
# 1          20.064516               6.0              19.0          12.870968
# 2           8.202299               7.0              16.0          10.800000
# 3          29.055914              -5.0              15.0           2.354839
# 4          30.850529              -9.0              13.0           2.785714
#
#    Temp avg (°C)var         ...           Wind (km/h) lowmean  \
# 0         13.956989         ...                     27.000000
# 1         14.582796         ...                     23.516129
# 2          5.889655         ...                     25.866667
# 3         24.303226         ...                     28.580645
# 4         24.322751         ...                     27.928571
#
#    Wind (km/h) lowvar  Wind (km/h) avgmin  Wind (km/h) avgmax  \
# 0           35.066667                 4.0                18.0
# 1           42.724731                 2.0                19.0
# 2           41.429885                 4.0                25.0
# 3           36.651613                 6.0                23.0
# 4           47.253968                 6.0                22.0
#
#    Wind (km/h) avgmean  Wind (km/h) avgvar  Wind (km/h) highmin  \
# 0            12.000000           12.200000                 21.0
# 1             9.677419           16.025806                 14.0
# 2            11.133333           25.636782                 21.0
# 3            13.451613           19.189247                 24.0
# 4            12.214286           21.656085                 24.0
#
#    Wind (km/h) highmax  Wind (km/h) highmean  Wind (km/h) highvar
# 0                 60.0             39.322581            96.625806
# 1                 71.0             34.419355           110.918280
# 2                 63.0             36.733333           108.685057
# 3                 64.0             42.838710            97.473118
# 4                 77.0             41.642857           167.349206
#
# [5 rows x 74 columns]

# %% [markdown]
# ### Taking Only mean of all Columns

# %%
weatherData_avg = weatherData_final.groupby(['Year', 'Month']).agg('mean').reset_index()
weatherData_avg['Month'] = weatherData_avg['Month'].astype('int64')
weatherData_avg.dtypes
# Out:
# Year                      int64
# Month                     int64
# Temp high (°C)          float64
# Temp avg (°C)           float64
# Temp low (°C)           float64
# Dew Point high (°C)     float64
# Dew Point avg (°C)      float64
# Dew Point low (°C)      float64
# Humidity_high           float64
# Humidity_avg            float64
# Humidity_low            float64
# Sea Level Press high    float64
# Sea Level Press avg     float64
# Sea Level Press low     float64
# Visibility (km) high    float64
# Visibility (km) avg     float64
# Visibility (km) low     float64
# Wind (km/h) low         float64
# Wind (km/h) avg         float64
# Wind (km/h) high        float64
# Precip (mm) sum         float64
# dtype: object

# %%
########################### ------------------------------------------- ##################################

# %% [markdown]
# # Events_Holidays Data

# %% [markdown]
# ## Load Data

# %%
data = pd.read_excel('C:\\Users\\HP\Desktop\\PHD Hackathon\\Data Science\\PhD_Train_Data\\Events_HolidaysData.xlsx')
data.head()
# Out:
#    Year  MonthDate                       Event      DayCategory
# 0  2009 2001-01-01              New Year's Day  Federal Holiday
# 1  2009 2019-01-01  Martin Luther King Jr. Day  Federal Holiday
# 2  2009 2014-02-01             Valentine's Day            Event
# 3  2009 2016-02-01             Presidents' Day  Federal Holiday
# 4  2009 2012-04-01               Easter Sunday            Event

# %% [markdown]
# ## Exclude 2016 Data

# %%
holiday_data = data.loc[0:129, ]
holiday_data.tail()
# Out:
#      Year  MonthDate                    Event      DayCategory
# 125  2015 2026-11-01         Thanksgiving Day  Federal Holiday
# 126  2015 2024-12-01            Christmas Eve            Event
# 127  2015 2025-12-01            Christmas Day  Federal Holiday
# 128  2015 2026-12-01  Day After Christmas Day            Event
# 129  2015 1931-12-01           New Year's Eve            Event

# %% [markdown]
# ## EDA and Preprocessing

# %%
print('Hape Of DataFrame', holiday_data.shape)
holiday_data.dtypes
# Out:
# Hape Of DataFrame (130, 4)
# Year                    int64
# MonthDate      datetime64[ns]
# Event                  object
# DayCategory            object
# dtype: object

# %%
print(holiday_data.Year.unique(), '\n')
print(np.min(holiday_data.MonthDate), '\n')
print(np.max(holiday_data.MonthDate), '\n')
print(len(holiday_data.Event.unique()), '\n')
print(holiday_data.DayCategory.unique())
# Out:
# [2009 2010 2011 2012 2013 2014 2015]
#
# 1930-05-01 00:00:00
#
# 2028-11-01 00:00:00
#
# 23
#
# ['Federal Holiday' 'Event']

# %% [markdown]
# ## Extract Month & Day From MonthDate Column

# %%
holiday_data.MonthDate = holiday_data.MonthDate.astype(str).str[2:7]

holiday_data['Month'] = holiday_data['MonthDate'].str[3:5]
holiday_data['Day'] = holiday_data['MonthDate'].str[0:2]
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\pandas\core\generic.py:3110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
holiday_data.head()
# Out:
#    Year MonthDate                       Event      DayCategory Month Day
# 0  2009     01-01              New Year's Day  Federal Holiday    01  01
# 1  2009     19-01  Martin Luther King Jr. Day  Federal Holiday    01  19
# 2  2009     14-02             Valentine's Day            Event    02  14
# 3  2009     16-02             Presidents' Day  Federal Holiday    02  16
# 4  2009     12-04               Easter Sunday            Event    04  12

# %%
holiday_data.dtypes
# Out:
# Year            int64
# MonthDate      object
# Event          object
# DayCategory    object
# Month          object
# Day            object
# dtype: object

# %%
vals_to_replace1 = {'01':'1','02':'2','03':'3','04':'4','05':'5','06':'6','07':'7','08':'8','09':'9','10':'10','11':'11','12':'12'}
holiday_data['Month'] = holiday_data['Month'].apply(lambda x: vals_to_replace1[x])
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
holiday_data.head()
# Out:
#    Year MonthDate                       Event      DayCategory Month Day
# 0  2009     01-01              New Year's Day  Federal Holiday     1  01
# 1  2009     19-01  Martin Luther King Jr. Day  Federal Holiday     1  19
# 2  2009     14-02             Valentine's Day            Event     2  14
# 3  2009     16-02             Presidents' Day  Federal Holiday     2  16
# 4  2009     12-04               Easter Sunday            Event     4  12

# %% [markdown]
# ### Column TypeCasting

# %%
holiday_data[['Year']] = holiday_data['Year'].astype('int64')
holiday_data[['Month']] = holiday_data['Month'].astype('int64')
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\HP\Anaconda3\lib\site-packages\pandas\core\indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ## Data Reshaping

# %%
holiday_pivot = pivot_table(holiday_data, values = ['Day'], index = ['Year', 'Month'], columns = ['DayCategory'], 
                            aggfunc=np.count_nonzero, fill_value=0)
holiday_pivot.head()
# Out:
#               Day
# DayCategory Event Federal Holiday
# Year Month
# 2009 1          0               2
#      2          1               1
#      4          1               0
#      5          1               1
#      6          1               0

# %%
holiday_pivot.columns = ['Event', 'Federal Holiday']
holiday_pivot = holiday_pivot.reset_index()
holiday_pivot.head()
# Out:
#    Year  Month  Event  Federal Holiday
# 0  2009      1      0                2
# 1  2009      2      1                1
# 2  2009      4      1                0
# 3  2009      5      1                1
# 4  2009      6      1                0

# %% [markdown]
# ### Extract New Features

# %%
holiday_pivot['Event_Yes_No'] = holiday_pivot['Event'].apply(lambda x: 'No' if x==0 else 'Yes')
holiday_pivot['Federal Holiday_Yes_No'] = holiday_pivot['Federal Holiday'].apply(lambda x: 'No' if x==0 else 'Yes')
# holiday_pivot = holiday_pivot.reset_index()
holiday_pivot.head()
# Out:
#    Year  Month  Event  Federal Holiday Event_Yes_No Federal Holiday_Yes_No
# 0  2009      1      0                2           No                    Yes
# 1  2009      2      1                1          Yes                    Yes
# 2  2009      4      1                0          Yes                     No
# 3  2009      5      1                1          Yes                    Yes
# 4  2009      6      1                0          Yes                     No

# %% [markdown]
# # Macro Economic Data

# %% [markdown]
# ## Load Data

# %%
macroEconomincData = pd.read_excel('C:\\Users\\HP\Desktop\\PHD Hackathon\\Data Science\\PhD_Train_Data\\MacroEconomicData.xlsx', 
                             na_values=['?', ' '], parse_dates=['Year-Month'])
print(macroEconomincData.shape)
macroEconomincData.head()
# Out:
# (96, 18)
#   Year-Month  Monthly Nominal GDP Index (inMillion$)  \
# 0 2009-01-01                            14421.752895
# 1 2009-02-01                            14389.200466
# 2 2009-03-01                            14340.701639
# 3 2009-04-01                            14326.815525
# 4 2009-05-01                            14345.904809
#
#    Monthly Real GDP Index (inMillion$)      CPI PartyInPower  \
# 0                         14407.053343  233.402    Democrats
# 1                         14366.176571  234.663    Democrats
# 2                         14351.786822  235.067    Democrats
# 3                         14351.601731  235.582    Democrats
# 4                         14368.123959  235.975    Democrats
#
#    unemployment rate  CommercialBankInterestRateonCreditCardPlans  \
# 0                7.8                                        12.03
# 1                8.3                                        12.97
# 2                8.7                                        12.97
# 3                9.0                                        12.97
# 4                9.4                                        13.32
#
#    Finance Rate on Personal Loans at Commercial Banks, 24 Month Loan  \
# 0                                              11.44
# 1                                              11.05
# 2                                              11.05
# 3                                              11.05
# 4                                              11.25
#
#    Earnings or wages  in dollars per hour  \
# 0                                   22.05
# 1                                   22.22
# 2                                   22.22
# 3                                   22.13
# 4                                   22.04
#
#    AdvertisingExpenses (in Thousand Dollars)  \
# 0                                      137.0
# 1                                      200.0
# 2                                        NaN
# 3                                      214.0
# 4                                        NaN
#
#    Cotton Monthly Price - US cents per Pound(lbs)  Change(in%)  \
# 0                                           57.70         4.02
# 1                                           55.21        -4.32
# 2                                           51.50        -6.72
# 3                                           56.78        10.25
# 4                                           61.95         9.11
#
#    Average upland planted(million acres)  \
# 0                                  9.296
# 1                                  9.296
# 2                                  9.296
# 3                                  9.296
# 4                                  9.297
#
#    Average upland harvested(million acres)  yieldperharvested acre  \
# 0                                    7.559                     799
# 1                                    7.559                     799
# 2                                    7.559                     799
# 3                                    7.559                     787
# 4                                    7.400                     803
#
#    Production (in  480-lb netweright in million bales)  \
# 0                                             12.589
# 1                                             12.589
# 2                                             12.589
# 3                                             12.400
# 4                                             12.384
#
#    Mill use  (in  480-lb netweright in million bales)  Exports
# 0                                               4.17    11.550
# 1                                               3.87    11.100
# 2                                               3.72    11.650
# 3                                               3.62    12.225
# 4                                               3.52    12.300

# %% [markdown]
# ### Excluding 2016 Records

# %%
economincData = macroEconomincData.loc[0:83,]   # Selecting till 2015 only.
economincData.tail()
# Out:
#    Year-Month  Monthly Nominal GDP Index (inMillion$)  \
# 79 2015-08-01                            18201.392888
# 80 2015-09-01                            18317.816120
# 81 2015-10-01                            18278.304270
# 82 2015-11-01                            18266.244605
# 83 2015-12-01                            18317.129125
#
#     Monthly Real GDP Index (inMillion$)      CPI PartyInPower  \
# 79                         16505.537615  261.347    Democrats
# 80                         16601.489879  261.887    Democrats
# 81                         16540.859723  261.515    Democrats
# 82                         16524.199494  261.009    Democrats
# 83                         16578.004544  259.941    Democrats
#
#     unemployment rate  CommercialBankInterestRateonCreditCardPlans  \
# 79                5.1                                        12.10
# 80                5.0                                        12.10
# 81                5.0                                        12.10
# 82                5.0                                        12.22
# 83                5.0                                        12.22
#
#     Finance Rate on Personal Loans at Commercial Banks, 24 Month Loan  \
# 79                                               9.80
# 80                                               9.80
# 81                                               9.80
# 82                                               9.66
# 83                                               9.66
#
#     Earnings or wages  in dollars per hour  \
# 79                                   25.04
# 80                                   25.05
# 81                                   25.14
# 82                                   25.38
# 83                                   25.21
#
#     AdvertisingExpenses (in Thousand Dollars)  \
# 79                                        NaN
# 80                                        NaN
# 81                                      183.0
# 82                                        NaN
# 83                                        NaN
#
#     Cotton Monthly Price - US cents per Pound(lbs)  Change(in%)  \
# 79                                           71.82        -0.73
# 80                                           68.74        -4.29
# 81                                           69.03         0.42
# 82                                           69.22         0.28
# 83                                           70.39         1.69
#
#     Average upland planted(million acres)  \
# 79                                  8.750
# 80                                  8.398
# 81                                  8.398
# 82                                  8.398
# 83                                  8.398
#
#     Average upland harvested(million acres)  yieldperharvested acre  \
# 79                                    7.749                     784
# 80                                    8.012                     777
# 81                                    8.012                     772
# 82                                    7.995                     770
# 83                                    7.995                     755
#
#     Production (in  480-lb netweright in million bales)  \
# 79                                             12.650
# 80                                             12.977
# 81                                             12.887
# 82                                             12.830
# 83                                             12.580
#
#     Mill use  (in  480-lb netweright in million bales)  Exports
# 79                                              3.675     9.475
# 80                                              3.675     9.700
# 81                                              3.675     9.700
# 82                                              3.675     9.700
# 83                                              3.675     9.500

# %% [markdown]
# ## EDA and Preprocessing

# %%
economincData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 18 columns):
# Year-Month                                                           84 non-null datetime64[ns]
# Monthly Nominal GDP Index (inMillion$)                               84 non-null float64
# Monthly Real GDP Index (inMillion$)                                  84 non-null float64
# CPI                                                                  84 non-null float64
# PartyInPower                                                         84 non-null object
# unemployment rate                                                    84 non-null float64
# CommercialBankInterestRateonCreditCardPlans                          84 non-null float64
# Finance Rate on Personal Loans at Commercial Banks, 24 Month Loan    84 non-null float64
# Earnings or wages  in dollars per hour                               84 non-null float64
# AdvertisingExpenses (in Thousand Dollars)                            11 non-null float64
# Cotton Monthly Price - US cents per Pound(lbs)                       84 non-null float64
# Change(in%)                                                          84 non-null float64
# Average upland planted(million acres)                                84 non-null float64
# Average upland harvested(million acres)                              84 non-null float64
# yieldperharvested acre                                               84 non-null int64
# Production (in  480-lb netweright in million bales)                  84 non-null float64
# Mill use  (in  480-lb netweright in million bales)                   84 non-null float64
# Exports                                                              84 non-null float64
# dtypes: datetime64[ns](1), float64(15), int64(1), object(1)
# memory usage: 11.9+ KB

# %% [markdown]
# ### Checking Null Values and unique values

# %%
print(economincData.PartyInPower.unique())
economincData['AdvertisingExpenses (in Thousand Dollars)'].isnull().sum()/len(economincData)*100
# Out:
# ['Democrats']
# 86.90476190476191

# %% [markdown]
# ### Extract Month and Year Columns

# %%
economincData['Year'] = economincData['Year-Month'].dt.year
economincData['Month'] = economincData['Year-Month'].dt.month
economincData.head()
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   Year-Month  Monthly Nominal GDP Index (inMillion$)  \
# 0 2009-01-01                            14421.752895
# 1 2009-02-01                            14389.200466
# 2 2009-03-01                            14340.701639
# 3 2009-04-01                            14326.815525
# 4 2009-05-01                            14345.904809
#
#    Monthly Real GDP Index (inMillion$)      CPI PartyInPower  \
# 0                         14407.053343  233.402    Democrats
# 1                         14366.176571  234.663    Democrats
# 2                         14351.786822  235.067    Democrats
# 3                         14351.601731  235.582    Democrats
# 4                         14368.123959  235.975    Democrats
#
#    unemployment rate  CommercialBankInterestRateonCreditCardPlans  \
# 0                7.8                                        12.03
# 1                8.3                                        12.97
# 2                8.7                                        12.97
# 3                9.0                                        12.97
# 4                9.4                                        13.32
#
#    Finance Rate on Personal Loans at Commercial Banks, 24 Month Loan  \
# 0                                              11.44
# 1                                              11.05
# 2                                              11.05
# 3                                              11.05
# 4                                              11.25
#
#    Earnings or wages  in dollars per hour  \
# 0                                   22.05
# 1                                   22.22
# 2                                   22.22
# 3                                   22.13
# 4                                   22.04
#
#    AdvertisingExpenses (in Thousand Dollars)  \
# 0                                      137.0
# 1                                      200.0
# 2                                        NaN
# 3                                      214.0
# 4                                        NaN
#
#    Cotton Monthly Price - US cents per Pound(lbs)  Change(in%)  \
# 0                                           57.70         4.02
# 1                                           55.21        -4.32
# 2                                           51.50        -6.72
# 3                                           56.78        10.25
# 4                                           61.95         9.11
#
#    Average upland planted(million acres)  \
# 0                                  9.296
# 1                                  9.296
# 2                                  9.296
# 3                                  9.296
# 4                                  9.297
#
#    Average upland harvested(million acres)  yieldperharvested acre  \
# 0                                    7.559                     799
# 1                                    7.559                     799
# 2                                    7.559                     799
# 3                                    7.559                     787
# 4                                    7.400                     803
#
#    Production (in  480-lb netweright in million bales)  \
# 0                                             12.589
# 1                                             12.589
# 2                                             12.589
# 3                                             12.400
# 4                                             12.384
#
#    Mill use  (in  480-lb netweright in million bales)  Exports  Year  Month
# 0                                               4.17    11.550  2009      1
# 1                                               3.87    11.100  2009      2
# 2                                               3.72    11.650  2009      3
# 3                                               3.62    12.225  2009      4
# 4                                               3.52    12.300  2009      5

# %% [markdown]
# ### Drop Unnecessary Columns [ PartyInPower, Year-Month ]

# %%
economincData = economincData.drop('PartyInPower', axis=1)    # Contains Only One Value In It.
economincData = economincData.drop('Year-Month', axis=1)      # Date and Month are Seperated as New Columns
economincData = economincData.drop('AdvertisingExpenses (in Thousand Dollars)',axis=1)# Do not have proper correlation and had 85% nulls. 
economincData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 17 columns):
# Monthly Nominal GDP Index (inMillion$)                               84 non-null float64
# Monthly Real GDP Index (inMillion$)                                  84 non-null float64
# CPI                                                                  84 non-null float64
# unemployment rate                                                    84 non-null float64
# CommercialBankInterestRateonCreditCardPlans                          84 non-null float64
# Finance Rate on Personal Loans at Commercial Banks, 24 Month Loan    84 non-null float64
# Earnings or wages  in dollars per hour                               84 non-null float64
# Cotton Monthly Price - US cents per Pound(lbs)                       84 non-null float64
# Change(in%)                                                          84 non-null float64
# Average upland planted(million acres)                                84 non-null float64
# Average upland harvested(million acres)                              84 non-null float64
# yieldperharvested acre                                               84 non-null int64
# Production (in  480-lb netweright in million bales)                  84 non-null float64
# Mill use  (in  480-lb netweright in million bales)                   84 non-null float64
# Exports                                                              84 non-null float64
# Year                                                                 84 non-null int64
# Month                                                                84 non-null int64
# dtypes: float64(14), int64(3)
# memory usage: 11.2 KB

# %% [markdown]
# ### Outliers Identification Using Box Plot

# %%
num_cols = economincData.iloc[:, 0:-2]
labels = num_cols.columns
scale = MinMaxScaler()
num_cols_scaled = pd.DataFrame(scale.fit_transform(num_cols), columns=labels)
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
sns.set(font_scale=2)

# %%
fig, ax = plt.subplots(figsize = (7,18))
sns.boxplot(data = num_cols_scaled, orient='h', palette='Set2')
sns.set(font_scale=2)
ax.set_title('Box Plot For Numeric Variables', fontsize = 25)
plt.show()

# %% [markdown]
# ### Finding Correlations

# %%
corr = num_cols.corr()
corr.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row0_col0 {
#             background-color:  #023858;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row0_col1 {
#             background-color:  #023858;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row0_col2 {
#             background-color:  #023d60;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row0_col3 {
#             background-color:  #fff7fb;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row0_col4 {
#             background-color:  #faf2f8;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row0_col5 {
#             background-color:  #fff7fb;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row0_col6 {
#             background-color:  #02395a;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row0_col7 {
#             background-color:  #fff7fb;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row0_col8 {
#             background-color:  #f7f0f7;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row0_col9 {
#             background-color:  #cdd0e5;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row0_col10 {
#             background-color:  #f6eff7;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row0_col11 {
#             background-color:  #fdf5fa;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row0_col12 {
#             background-color:  #f9f2f8;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row0_col13 {
#             background-color:  #71a8ce;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row0_col14 {
#             background-color:  #fff7fb;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row1_col0 {
#             background-color:  #023858;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row1_col1 {
#             background-color:  #023858;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row1_col2 {
#             background-color:  #023f64;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row1_col3 {
#             background-color:  #fef6fb;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row1_col4 {
#             background-color:  #f7f0f7;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row1_col5 {
#             background-color:  #fef6fb;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row1_col6 {
#             background-color:  #023a5b;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row1_col7 {
#             background-color:  #fef6fb;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row1_col8 {
#             background-color:  #f6eff7;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row1_col9 {
#             background-color:  #ced0e6;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row1_col10 {
#             background-color:  #f4edf6;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row1_col11 {
#             background-color:  #fff7fb;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row1_col12 {
#             background-color:  #f7f0f7;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row1_col13 {
#             background-color:  #71a8ce;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row1_col14 {
#             background-color:  #fdf5fa;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row2_col0 {
#             background-color:  #023d60;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row2_col1 {
#             background-color:  #023f64;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row2_col2 {
#             background-color:  #023858;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row2_col3 {
#             background-color:  #f9f2f8;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row2_col4 {
#             background-color:  #fff7fb;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row2_col5 {
#             background-color:  #fdf5fa;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row2_col6 {
#             background-color:  #023e62;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row2_col7 {
#             background-color:  #f5eef6;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row2_col8 {
#             background-color:  #fff7fb;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row2_col9 {
#             background-color:  #a4bcda;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row2_col10 {
#             background-color:  #f1ebf5;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row2_col11 {
#             background-color:  #f5eff6;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row2_col12 {
#             background-color:  #f3edf5;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row2_col13 {
#             background-color:  #8eb3d5;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row2_col14 {
#             background-color:  #fdf5fa;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row3_col0 {
#             background-color:  #fff7fb;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row3_col1 {
#             background-color:  #fff7fb;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row3_col2 {
#             background-color:  #fff7fb;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row3_col3 {
#             background-color:  #023858;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row3_col4 {
#             background-color:  #045788;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row3_col5 {
#             background-color:  #045483;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row3_col6 {
#             background-color:  #fff7fb;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row3_col7 {
#             background-color:  #88b1d4;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row3_col8 {
#             background-color:  #9ebad9;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row3_col9 {
#             background-color:  #b4c4df;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row3_col10 {
#             background-color:  #ece7f2;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row3_col11 {
#             background-color:  #e0dded;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row3_col12 {
#             background-color:  #ebe6f2;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row3_col13 {
#             background-color:  #fff7fb;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row3_col14 {
#             background-color:  #187cb6;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row4_col0 {
#             background-color:  #f2ecf5;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row4_col1 {
#             background-color:  #f0eaf4;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row4_col2 {
#             background-color:  #fdf5fa;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row4_col3 {
#             background-color:  #045585;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row4_col4 {
#             background-color:  #023858;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row4_col5 {
#             background-color:  #0567a2;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row4_col6 {
#             background-color:  #f2ecf5;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row4_col7 {
#             background-color:  #a1bbda;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row4_col8 {
#             background-color:  #75a9cf;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row4_col9 {
#             background-color:  #fff7fb;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row4_col10 {
#             background-color:  #fff7fb;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row4_col11 {
#             background-color:  #efe9f3;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row4_col12 {
#             background-color:  #fef6fb;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row4_col13 {
#             background-color:  #f1ebf4;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row4_col14 {
#             background-color:  #2484ba;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00row5_col0 {
#             background-color:  #f6eff7;
#         }    #T_0ef1a04a_2b8d_11e9_9142_fc15b4e90c00ro

# %%
########################### ------------------------------------------- ##################################

# %% [markdown]
# # Train Dataset  [ Cloths Sales ]

# %% [markdown]
# ## Load Data

# %%
trainDf = pd.read_csv('C:\\Users\\HP\Desktop\\PHD Hackathon\\Data Science\\PhD_Train_Data\\Train.csv', na_values=[' '])
trainDf.head()
# Out:
#    Year  Month ProductCategory  Sales(In ThousandDollars)
# 0  2009      1   WomenClothing                     1755.0
# 1  2009      1     MenClothing                      524.0
# 2  2009      1   OtherClothing                      936.0
# 3  2009      2   WomenClothing                     1729.0
# 4  2009      2     MenClothing                      496.0

# %%
trainDf.isnull().sum()
# Out:
# Year                          0
# Month                         0
# ProductCategory               0
# Sales(In ThousandDollars)    13
# dtype: int64

# %%
trainDf['YearMonth'] = trainDf['Year'].map(str) + "-" + trainDf['Month'].map(str)
trainDf['YearMonth'] = pd.to_datetime(trainDf['YearMonth'], format='%Y-%m')
trainDf.head()
# Out:
#    Year  Month ProductCategory  Sales(In ThousandDollars)  YearMonth
# 0  2009      1   WomenClothing                     1755.0 2009-01-01
# 1  2009      1     MenClothing                      524.0 2009-01-01
# 2  2009      1   OtherClothing                      936.0 2009-01-01
# 3  2009      2   WomenClothing                     1729.0 2009-02-01
# 4  2009      2     MenClothing                      496.0 2009-02-01

# %% [markdown]
# ### Each Year, Each Month, Each Product Product Sales

# %%
plt.subplots(figsize = (15, 7))
sns.lineplot(x="YearMonth", y="Sales(In ThousandDollars)", hue="ProductCategory", data = trainDf)
plt.yticks(np.arange(500,5000, 500))
plt.title('Year Vs Product Category Sales')
plt.show()

# %%
trainDf.dtypes
# Out:
# Year                                  int64
# Month                                 int64
# ProductCategory                      object
# Sales(In ThousandDollars)           float64
# YearMonth                    datetime64[ns]
# dtype: object

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Fill Missing Values
# - Fill Missing Values By Grouping On Product Category.

# %%
trainDf['Sales(In ThousandDollars)'] = trainDf.groupby('ProductCategory')['Sales(In ThousandDollars)'].apply(lambda x: x.fillna(x.mean()))
trainDf.isnull().any()
# Out:
# Year                         False
# Month                        False
# ProductCategory              False
# Sales(In ThousandDollars)    False
# YearMonth                    False
# dtype: bool

# %% [markdown]
# ## Data Reshaping

# %%
train_pivoted = pivot_table(trainDf, index = ['Year', 'Month'], values = ['Sales(In ThousandDollars)'], columns = ['ProductCategory'])
train_pivoted.head()
# Out:
#                 Sales(In ThousandDollars)
# ProductCategory               MenClothing OtherClothing WomenClothing
# Year Month
# 2009 1                              524.0         936.0        1755.0
#      2                              496.0         859.0        1729.0
#      3                              542.0         921.0        2256.0
#      4                              669.0         914.0        2662.0
#      5                              650.0         989.0        2732.0

# %%
train_pivoted.shape
# Out:
# (84, 3)

# %%
train_pivoted.columns = ['MenClothing_Sales', 'OtherClothing_Sales', 'WomenClothing_Sales']
train_pivoted = train_pivoted.reset_index()
train_pivoted.head()
# Out:
#    Year  Month  MenClothing_Sales  OtherClothing_Sales  WomenClothing_Sales
# 0  2009      1              524.0                936.0               1755.0
# 1  2009      2              496.0                859.0               1729.0
# 2  2009      3              542.0                921.0               2256.0
# 3  2009      4              669.0                914.0               2662.0
# 4  2009      5              650.0                989.0               2732.0

# %%
train_pivoted.columns
# Out:
# Index(['Year', 'Month', 'MenClothing_Sales', 'OtherClothing_Sales',
#        'WomenClothing_Sales'],
#       dtype='object')

# %%
pyplot.figure(figsize=(10, 7))
pyplot.subplot(211)
plot_acf(train_pivoted['WomenClothing_Sales'], ax = pyplot.gca())
pyplot.show()

# %%
Observations:

from the above plot, it is observed that after every 12th point there is correlation.
Means WomenClothing Has seasonality, so Bolt winter's technique can be used..

WomenClothing Has seasonality, so Bolt winters technique can be used.

# %%
Observations:

from the above plot, it is observed that after every 12th point there is correlation.
Means WomenClothing Has seasonality, so Bolt winter's technique can be used..

WomenClothing Has seasonality, so Bolt winters technique can be used.

pyplot.figure(figsize=(10, 7))
pyplot.subplot(211)
plot_pacf(train_pivoted['WomenClothing_Sales'], ax = pyplot.gca())
pyplot.show()

# %% [markdown]
# ### Create Date Column

# %%
train_pivoted['Date'] = train_pivoted['Year'].map(str) + "-" + train_pivoted['Month'].map(str)
train_pivoted['Date'] = pd.to_datetime(train_pivoted['Date'], format='%Y-%m')
train_pivoted.tail()
# Out:
#     Year  Month  MenClothing_Sales  OtherClothing_Sales  WomenClothing_Sales  \
# 79  2015      8              712.0               1405.0               3897.0
# 80  2015      9              690.0               1261.0               3881.0
# 81  2015     10              800.0               1283.0               4372.0
# 82  2015     11              643.0               1478.0               4401.0
# 83  2015     12              967.0               1680.0               5874.0
#
#     Sales(In ThousandDollars)       Date
# 79                     6014.0 2015-08-01
# 80                     5832.0 2015-09-01
# 81                     6455.0 2015-10-01
# 82                     6522.0 2015-11-01
# 83                     8521.0 2015-12-01

# %%
train_pivoted['Sales(In ThousandDollars)']
# Out:
# ProductCategory  MenClothing  OtherClothing  WomenClothing
# Year Month
# 2009 1                524.00     936.000000      1755.0000
#      2                496.00     859.000000      1729.0000
#      3                542.00     921.000000      2256.0000
#      4                669.00     914.000000      2662.0000
#      5                650.00     989.000000      2732.0000
#      6                607.00     932.000000      2220.0000
#      7                575.00     901.000000      2164.0000
#      8                551.00     865.000000      2371.0000
#      9                579.00     819.000000      2421.0000
#      10               610.00     914.000000      2579.0000
#      11               620.00     955.000000      2521.0000
#      12               930.00    1351.000000      3390.0000
# 2010 1                476.00     945.000000      2142.0000
#      2                471.00     869.000000      2413.0000
#      3                568.00     941.000000      3102.0000
#      4                630.00    1143.506329      3409.8125
#      5                627.00     991.000000      3221.0000
#      6                598.00     984.000000      2756.0000
#      7                544.00     937.000000      2749.0000
#      8                678.95     897.000000      2807.0000
#      9                563.00     839.000000      2919.0000
#      10               634.00     930.000000      3071.0000
#      11               669.00    1035.000000      3276.0000
#      12               988.00    1398.000000      4360.0000
# 2011 1                487.00     968.000000      2193.0000
#      2                497.00     878.000000      2620.0000
#      3                599.00    1064.000000      3266.0000
#      4                690.00     985.000000      3414.0000
#      5                677.00    1027.000000      3340.0000
#      6                678.95    1143.506329      3232.0000
# ...                      ...            ...            ...
# 2013 7                648.00    1126.000000      3320.0000
#      8                687.00    1311.000000      3539.0000
#      9                681.00    1043.000000      3720.0000
#      10               785.00    1143.506329      3590.0000
#      11               798.00    1209.000000      3834.0000
#      12              1085.00    1566.000000      4865.0000
# 2014 1                573.00    1172.000000      2961.0000
#      2                636.00    1123.000000      3381.0000
#      3                702.00    1293.000000      4268.0000
#      4                785.00    1196.000000      4223.0000
#      5                801.00    1257.000000      4421.0000
#      6                702.00    1143.506329      3905.0000
#      7                655.00    1175.000000      3733.0000
#      8                692.00    1337.000000      4067.0000
#      9                678.95    1056.000000      4481.0000
#      10               757.00    1153.000000      4434.0000
#      11               803.00    1468.000000      4525.0000
#      12              1070.00    1967.000000      5664.0000
# 2015 1                560.00    1190.000000      3041.0000
#      2                602.00    1210.000000      3646.0000
#      3                645.00    1300.000000      4294.0000
#      4                701.00    1205.000000      3409.8125
#      5                800.00    1363.000000      4413.0000
#      6                716.00    1402.000000      3899.0000
#      7                661.00    1349.000000      3817.0000
#      8                712.00    1405.000000      3897.0000
#      9                690.00    1261.000000      3881.0000
#      10               800.00    1283.000000      4372.0000
#      11               643.00    1478.000000      4401.0000
#      12               967.00    1680.000000      5874.0000
#
# [84 rows x 3 columns]

# %%
single_col.to_csv('C:\\Users\\HP\\Desktop\\PHD Hackathon\\stationary.csv')

# %%
from pandas import Series
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from matplotlib import pyplot
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
pyplot.figure()
pyplot.subplot(211)
plot_acf(trainDf['Sales(In ThousandDollars)'], ax = pyplot.gca())
pyplot.show()

# %%
pyplot.subplot(212)
plot_pacf(trainDf['Sales(In ThousandDollars)'], ax = pyplot.gca())
pyplot.show()

# %% [markdown]
# ## EDA

# %%
train_pivoted.shape
# Out:
# (84, 7)

# %%
train_pivoted.dtypes
# Out:
# Year                                  int64
# Month                                 int64
# MenClothing_Sales                   float64
# OtherClothing_Sales                 float64
# WomenClothing_Sales                 float64
# Sales(In ThousandDollars)           float64
# Date                         datetime64[ns]
# dtype: object

# %%
train_pivoted.describe()
# Out:
#               Year      Month  MenClothing_Sales  OtherClothing_Sales  \
# count    84.000000  84.000000          84.000000            84.000000
# mean   2012.000000   6.500000         678.950000          1143.506329
# std       2.012012   3.472786         133.684388           210.143661
# min    2009.000000   1.000000         471.000000           819.000000
# 25%    2010.000000   3.750000         598.750000           984.750000
# 50%    2012.000000   6.500000         673.000000          1143.506329
# 75%    2014.000000   9.250000         711.250000          1258.000000
# max    2015.000000  12.000000        1085.000000          1967.000000
#
#        WomenClothing_Sales  Sales(In ThousandDollars)
# count            84.000000                  84.000000
# mean           3409.812500                5232.268829
# std             822.059859                1119.866117
# min            1729.000000                3084.000000
# 25%            2855.750000                4446.737500
# 50%            3385.500000                5125.906250
# 75%            3886.500000                5834.250000
# max            5874.000000                8701.000000

# %%
train_pivoted.isnull().sum()
# Out:
# Year                         0
# Month                        0
# MenClothing_Sales            0
# OtherClothing_Sales          0
# WomenClothing_Sales          0
# Sales(In ThousandDollars)    0
# Date                         0
# dtype: int64

# %%
train_pivoted['Sales(In ThousandDollars)'] = train_pivoted['MenClothing_Sales']+train_pivoted['OtherClothing_Sales']+train_pivoted['WomenClothing_Sales']  
train_pivoted.head()
# Out:
#    Year  Month  MenClothing_Sales  OtherClothing_Sales  WomenClothing_Sales  \
# 0  2009      1              524.0                936.0               1755.0
# 1  2009      2              496.0                859.0               1729.0
# 2  2009      3              542.0                921.0               2256.0
# 3  2009      4              669.0                914.0               2662.0
# 4  2009      5              650.0                989.0               2732.0
#
#    Sales(In ThousandDollars)       Date
# 0                     3215.0 2009-01-01
# 1                     3084.0 2009-02-01
# 2                     3719.0 2009-03-01
# 3                     4245.0 2009-04-01
# 4                     4371.0 2009-05-01

# %%
train_pivoted
# Out:
#                 Sales(In ThousandDollars)
# ProductCategory               MenClothing OtherClothing WomenClothing
# Year Month
# 2009 1                             524.00    936.000000     1755.0000
#      2                             496.00    859.000000     1729.0000
#      3                             542.00    921.000000     2256.0000
#      4                             669.00    914.000000     2662.0000
#      5                             650.00    989.000000     2732.0000
#      6                             607.00    932.000000     2220.0000
#      7                             575.00    901.000000     2164.0000
#      8                             551.00    865.000000     2371.0000
#      9                             579.00    819.000000     2421.0000
#      10                            610.00    914.000000     2579.0000
#      11                            620.00    955.000000     2521.0000
#      12                            930.00   1351.000000     3390.0000
# 2010 1                             476.00    945.000000     2142.0000
#      2                             471.00    869.000000     2413.0000
#      3                             568.00    941.000000     3102.0000
#      4                             630.00   1143.506329     3409.8125
#      5                             627.00    991.000000     3221.0000
#      6                             598.00    984.000000     2756.0000
#      7                             544.00    937.000000     2749.0000
#      8                             678.95    897.000000     2807.0000
#      9                             563.00    839.000000     2919.0000
#      10                            634.00    930.000000     3071.0000
#      11                            669.00   1035.000000     3276.0000
#      12                            988.00   1398.000000     4360.0000
# 2011 1                             487.00    968.000000     2193.0000
#      2                             497.00    878.000000     2620.0000
#      3                             599.00   1064.000000     3266.0000
#      4                             690.00    985.000000     3414.0000
#      5                             677.00   1027.000000     3340.0000
#      6                             678.95   1143.506329     3232.0000
# ...                                   ...           ...           ...
# 2013 7                             648.00   1126.000000     3320.0000
#      8                             687.00   1311.000000     3539.0000
#      9                             681.00   1043.000000     3720.0000
#      10                            785.00   1143.506329     3590.0000
#      11                            798.00   1209.000000     3834.0000
#      12                           1085.00   1566.000000     4865.0000
# 2014 1                             573.00   1172.000000     2961.0000
#      2                             636.00   1123.000000     3381.0000
#      3                             702.00   1293.000000     4268.0000
#      4                             785.00   1196.000000     4223.0000
#      5                             801.00   1257.000000     4421.0000
#      6                             702.00   1143.506329     3905.0000
#      7                             655.00   1175.000000     3733.0000
#      8                             692.00   1337.000000     4067.0000
#      9                             678.95   1056.000000     4481.0000
#      10                            757.00   1153.000000     4434.0000
#      11                            803.00   1468.000000     4525.0000
#      12                           1070.00   1967.000000     5664.0000
# 2015 1                             560.00   1190.000000     3041.0000
#      2                             602.00   1210.000000     3646.0000
#      3                             645.00   1300.000000     4294.0000
#      4                             701.00   1205.000000     3409.8125
#      5                             800.00   1363.000000     4413.0000
#      6                             716.00   1402.000000     3899.0000
#      7                             661.00   1349.000000     3817.0000
#      8                             712.00   1405.000000     3897.0000
#      9                             690.00   1261.000000     3881.0000
#      10                            800.00   1283.000000     4372.0000
#      11                            643.00   1478.000000     4401.0000
#      12                            967.00   1680.000000     5874.0000
#
# [84 rows x 3 columns]

# %% [markdown]
# ## Distribution Plots

# %% [markdown]
# ### Distribution Sales(In ThousandDollars)

# %%
plt.subplots(figsize = (10, 5))
plt.hist(train_pivoted['Sales(In ThousandDollars)'])
plt.xlabel('Sales In Thousand $', fontdict={'size':16})
plt.ylabel('Frequence',  fontdict={'size':16})
plt.yticks(np.arange(0, 25, 5))
plt.title('Sales(In ThousandDollars)',  fontdict={'size':20})
plt.show()

# %%
f, axes = plt.subplots(figsize=(24,6), nrows=1, ncols=3)

sns.distplot(train_pivoted.MenClothing_Sales, ax = axes[0], kde = False, color = 'green', bins=10).set_title('MenClothing_Sales')
sns.distplot(train_pivoted.WomenClothing_Sales, ax = axes[1], kde = False, color = 'red', bins=10).set_title("WomenClothing_Sales") 
sns.distplot(train_pivoted.OtherClothing_Sales, ax = axes[2], kde = False, color = 'blue', bins=10).set_title("OtherClothing_Sales") 

f.suptitle('Distribution Plots')
sns.set(font_scale = 1.8)
plt.show()

# %% [markdown]
# ### Year vs Sales Plot

# %%
plt.subplots(figsize = (12, 5))
sns.lineplot(x="Year", y="Sales(In ThousandDollars)", hue="ProductCategory", data = trainDf)
plt.yticks(np.arange(500,5000, 500))
plt.title('Year Vs Product Category Sales')
plt.show()
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.subplots(figsize = (12, 5))
sns.lineplot(x="Date", y="Sales(In ThousandDollars)", data = train_pivoted)
plt.yticks(np.arange(500,5000, 500))
plt.title('Year Vs Product Category Sales')
plt.show()

# %% [markdown]
# # Merge all Datasets Togeather

# %%
trainingDataFull = pd.merge(weatherData_avg, holiday_pivot, how='left', left_on=['Year','Month'], right_on = ['Year','Month'])
trainingDataFull = pd.merge(trainingDataFull, economincData, how='left', left_on=['Year','Month'], right_on = ['Year','Month'])
trainingDataFull = pd.merge(trainingDataFull, train_pivoted, how='left', left_on=['Year','Month'], right_on = ['Year','Month'])

# %%
trainingDataFull
# Out:
#     Year  Month  Temp high (°C)  Temp avg (°C)  Temp low (°C)  \
# 0   2009      1        0.741935      -2.096774      -5.322581
# 1   2009     10       16.258065      12.870968       9.354839
# 2   2009     11       13.733333      10.800000       7.566667
# 3   2009     12        5.451613       2.354839      -1.032258
# 4   2009      2        6.964286       2.785714      -1.642857
# 5   2009      3        9.838710       5.967742       1.774194
# 6   2009      4       17.100000      12.733333       7.833333
# 7   2009      5       21.354839      17.000000      12.483871
# 8   2009      6       23.666667      19.866667      15.833333
# 9   2009      7       26.838710      22.741935      18.225806
# 10  2009      8       27.967742      24.387097      20.548387
# 11  2009      9       22.766667      19.233333      15.333333
# 12  2010      1        3.387097       0.451613      -2.774194
# 13  2010     10       18.419355      14.612903      10.645161
# 14  2010     11       12.033333       9.000000       5.633333
# 15  2010     12        3.096774       0.612903      -2.322581
# 16  2010      2        3.321429       0.821429      -1.964286
# 17  2010      3       12.806452       9.258065       5.193548
# 18  2010      4       19.566667      14.466667       9.133333
# 19  2010      5       23.516129      18.612903      13.419355
# 20  2010      6       28.500000      23.800000      19.033333
# 21  2010      7       32.258065      27.548387      22.516129
# 22  2010      8       29.580645      25.290323      20.838710
# 23  2010      9       25.900000      21.800000      17.433333
# 24  2011      1        1.548387      -1.096774      -4.032258
# 25  2011     10       17.612903      14.096774      10.225806
# 26  2011     11       14.733333      11.166667       7.300000
# 27  2011     12        9.838710       6.483871       2.677419
# 28  2011      2        6.428571       2.428571      -2.035714
# 29  2011      3        9.967742       5.838710       1.451613
# ..   ...    ...             ...            ...            ...
# 54  2013      4       16.400000      11.833333       7.200000
# 55  2013      5       21.774194      17.258065      12.419355
# 56  2013      6       26.833333      22.733333      18.400000
# 57  2013      7       30.129032      26.580645      22.903226
# 58  2013      8       27.548387      23.838710      19.838710
# 59  2013      9       24.766667      20.066667      15.200000
# 60  2014      1        1.806452      -1.709677      -5.645161
# 61  2014     10       18.806452      15.451613      11.935484
# 62  2014     11       10.966667       7.533333       3.866667
# 63  2014     12        7.322581       4.870968       2.193548
# 64  2014      2        3.000000       0.000000      -3.428571
# 65  2014      3        7.548387       3.322581      -1.193548
# 66  2014      4       16.166667      11.466667       6.366667
# 67  2014      5       22.548387      17.935484      13.096774
# 68  2014      6       26.900000      22.633333      18.033333
# 69  2014      7       28.516129      24.645161      20.451613
# 70  2014      8       28.032258      23.741935      19.161290
# 71  2014      9       25.266667      21.066667      16.733333
# 72  2015      1        2.290323      -1.032258      -4.677419
# 73  2015     10       18.580645      14.483871      10.387097
# 74  2015     11       15.033333      11.633333       7.966667
# 75  2015     12       13.548387      10.548387       7.451613
# 76  2015      2        0.000000      -4.250000      -9.071429
# 77  2015      3        7.258065       3.516129      -0.612903
# 78  2015      4       17.066667      12.533333       7.833333
# 79  2015      5       25.677419      20.483871      14.774194
# 80  2015      6       25.800000      21.866667      17.733333
# 81  2015      7       29.967742      26.129032      22.129032
# 82  2015      8       30.516129      26.322581      21.677419
# 83  2015      9       28.133333      23.700000      18.966667
#
#     Dew Point high (°C)  Dew Point avg (°C)  Dew Point low (°C)  \
# 0             -6.096774           -9.903226          -14.000000
# 1              9.838710            7.032258            3.903226
# 2              7.000000            4.166667            1.433333
# 3             -0.935484           -4.677419           -8.709677
# 4             -2.464286           -6.392857          -10.571429
# 5              0.258065           -2.903226           -6.741935
# 6              6.233333            2.533333           -1.200000
# 7             12.967742           10.096774            6.516129
# 8             17.100000           15.366667           13.133333
# 9             18.838710           16.451613           13.612903
# 10            20.451613           18.483871           16.129032
# 11            15.066667           12.766667           10.133333
# 12            -4.935484           -7.258065          -10.354839
# 13            10.161290            7.096774            3.129032
# 14             3.966667            0.766667           -2.900000
# 15            -4.645161           -6.935484           -9.806452
# 16            -3.571429           -6.071429           -8.321429
# 17             2.967742           -0.290323           -3.516129
# 18             6.266667            3.133333           -1.333333
# 19            13.258065           10.096774            6.387097
# 20            18.166667           15.533333           12.166667
# 21            19.483871           17.387097           14.258065
# 22            19.161290           16.548387           13.419355
# 23            16.900000           13.700000           10.400000
# 24            -5.225806           -7.806452          -11.612903
# 25            10.387097            7.645161            4.161290
# 26             7.433333            4.366667            1.133333
# 27             3.935484           -0.516129           -4.548387
# 28            -2.535714           -6.857143          -12.392857
# 29             0.193548           -3.387097           -7.580645
# ..                  ...                 ...                 ...
# 54             5.266667            0.966667           -3.433333
# 55            12.064516            9.225806            5.774194
# 56            17.966667           15.366667           12.333333
# 57            21.354839           19.419355           16.774194
# 58            18.387097           15.548387           12.870968
# 59            14.233333           11.500000            8.500000
# 60            -5.322581           -9.483871          -13.806452
# 61            11.129032            8.225806            4.645161
# 62             2.500000           -1.833333           -5.600000
# 63             1.387097           -1.677419           -5.225806
# 64            -4.464286           -8.178571          -12.107143
# 65            -3.161290           -7.580645          -11.935484
# 66             5.066667            0.800000           -3.766667
# 67            11.774194            8.193548            4.677419
# 68            16.666667           14.133333           11.000000
# 69            18.806452           16.354839           13.483871
# 70            16.967742           14.677419           11.870968
# 71            15.766667           13.033333           10.066667
# 72            -5.548387           -9.612903          -14.741935
# 73             8.709677            5.516129            2.322581
# 74             7.200000            3.566667           -0.266667
# 75             7.419355            4.096774            0.645161
# 76            -8.285714          -12.428571          -17.535714
# 77            -1.193548           -6.096774          -11.451613
# 78             5.166667            0.800000           -3.566667
# 79            12.774194            9.870968            6.709677
# 80            17.133333           14.300000           10.833333
# 81            19.096774           16.548387           13.612903
# 82            17.580645           15.290323           12.709677
# 83            16.866667           14.400000           11.266667
#
#     Humidity_high  Humidity_avg            ...              \
# 0       71.774194     57.354839            ...
# 1       85.903226     69.354839            ...
# 2       80.466667     66.600000            ...
# 3       77.612903     61.741935            ...
# 4       69.535714     54.000000            ...
# 5       74.096774     57.064516            ...
# 6       75.466667     55.700000            ...
# 7       85.645161     68.516129            ...
# 8       95.200000     78.866667            ...
# 9       88.612903     70.806452            ...
# 10      88.870968     72.483871            ...
# 11      86.400000     69.700000            ...
# 12      71.290323     58.129032            ...
# 13      80.838710     63.645161            ...
# 14      74.800000     59.533333            ...
# 15      70.096774     58.322581            ...
# 16      75.071429     63.535714            ...
# 17      72.354839     58.290323            ...
# 18      73.533333     52.800000            ...
# 19      83.000000     62.741935            ...
# 20      82.766667     64.066667            ...
# 21      76.096774     58.032258            ...
# 22      80.387097     62.935484            ...
# 23      81.233333     63.566667            ...
# 24      75.483871     61.516129            ...
# 25      84.806452     67.903226            ...
# 26      79.733333     64.166667            ...
# 27      76.419355     62.483871            ...
# 28      69.250000     52.607143            ...
# 29      73.225806     56.096774            ...
# ..            ...           ...            ...
# 54      72.966667     53.900000            ...
# 55      82.677419     64.580645            ...
# 56      84.400000     66.933333            ...
# 57      83.709677     67.677419            ...
# 58      82.612903     64.516129            ...
# 59      78.033333     60.300000            ...
# 60      74.387097     58.903226            ...
# 61      78.290323     63.032258            ...
# 62      70.133333     54.466667            ...
# 63      77.225806     64.387097            ...
# 64      74.428571     58.392857            ...
# 65      63.032258     48.322581            ...
# 66      73.100000     54.200000            ...
# 67      76.354839     59.000000            ...
# 68      80.233333     62.966667            ...
# 69      80.451613     63.741935            ...
# 70      78.354839     60.806452            ...
# 71      78.666667     62.300000            ...
# 72      68.967742     53.645161            ...
# 73      71.483871     57.032258            ...
# 74      74.866667     60.300000            ...
# 75      78.645161     65.677419            ...
# 76      68.357143     53.892857            ...
# 77      72.612903     54.000000            ...
# 78      69.033333     50.866667            ...
# 79      74.354839     56.709677            ...
# 80      81.000000     65.033333            ...
# 81      74.354839     59.096774            ...
# 82      70.806452     54.870968            ...
# 83      75.066667     58.633333            ...
#
#     Average upland planted(million acres)  \
# 0                                   9.296
# 1                                   8.989
# 2                                   8.989
# 3                                   8.989
# 4                                   9.296
# 5                                   9.296
# 6                                   9.296
# 7                                   9.297
# 8                                   8.668
# 9                                   8.905
# 10                                  8.905
# 11                                  8.989
# 12                                  9.008
# 13                                 10.829
# 14                                 10.829
# 15                                 10.829
# 16                                  9.008
# 17                                  9.008
# 18                                  9.008
# 19                                  9.008
# 20                                 10.315
# 21                                 10.700
# 22                                 10.700
# 23                                 10.829
# 24                                 10.769
# 25                                 14.431
# 26                                 14.431
# 27                                 14.431
# 28                                 10.769
# 29                                 10.769
# ..                                    ...
# 54                                 12.077
# 55                                 12.076
# 56                                  9.820
# 57                                 10.025
# 58                                 10.015
# 59                                 10.136
# 60                                 10.206
# 61                                 10.818
# 62                                 10.818
# 63                                 10.818
# 64                                 10.206
# 65                                 10.206
# 66                                 10.206
# 67                                 10.206
# 68                                 10.943
# 69                                 11.191
# 70                                 11.191
# 71                                 10.818
# 72                                 10.845
# 73                                  8.398
# 74                                  8.398
# 75                                  8.398
# 76                                 10.845
# 77                                 10.845
# 78                                 10.845
# 79                                 10.845
# 80                                  9.399
# 81                                  8.850
# 82                                  8.750
# 83                                  8.398
#
#     Average upland harvested(million acres)  yieldperharvested acre  \
# 0                                     7.559                     799
# 1                                     7.586                     799
# 2                                     7.586                     767
# 3                                     7.586                     774
# 4                                     7.559                     799
# 5                                     7.559                     799
# 6                                     7.559                     787
# 7                                     7.400                     803
# 8                                     7.760                     796
# 9                                     7.753                     796
# 10                                    7.619                     809
# 11                                    7.582                     827
# 12                                    7.552                     763
# 13                                   10.566                     835
# 14                                   10.566                     814
# 15                                   10.566                     807
# 16                                    7.552                     763
# 17                                    7.552                     763
# 18                                    7.552                     747
# 19                                    7.391                     766
# 20                                    9.642                     806
# 21                                   10.193                     836
# 22                                   10.424                     831
# 23                                   10.566                     833
# 24                                   10.505                     814
# 25                                    9.562                     797
# 26                                    9.562                     781
# 27                                    9.562                     757
# 28                                   10.505                     814
# 29                                   10.505                     814
# ..                                      ...                     ...
# 54                                    9.190                     862
# 55                                    9.135                     869
# 56                                    7.896                     785
# 57                                    7.579                     815
# 58                                    7.519                     796
# 59                                    7.582                     777
# 60                                    7.465                     807
# 61                                    9.692                     776
# 62                                    9.692                     783
# 63                                    9.692                     760
# 64                                    7.465                     807
# 65                                    7.465                     807
# 66                                    7.465                     787
# 67                                    7.345                     802
# 68                                    8.594                     811
# 69                                    8.594                     804
# 70                                   10.065                     808
# 71                                    9.692                     790
# 72                                    9.518                     760
# 73                                    8.012                     772
# 74                                    7.995                     770
# 75                                    7.995                     755
# 76                                    9.518                     781
# 77                                    9.518                     781
# 78                                    9.518                     794
# 79                                    9.157                     826
# 80                                    8.451                     797
# 81                                    8.353                     807
# 82                                    7.749                     784
# 83                                    8.012                     777
#
#     Production (in  480-lb netweright in million bales)  \
# 0                                              12.589
# 1                                              12.631
# 2                                              12.129
# 3                                              12.225
# 4                                              12.589
# 5                                              12.589
# 6                                              12.400
# 7                                              12.384
# 8                                              12.876
# 9                                              12.863
# 10                                             12.840
# 11                                             13.071
# 12                                             12.011
# 13                                             18.375
# 14                                             17.920
# 15                                             17.770
# 16                                             12.011
# 17                                             12.011
# 18                                             11.751
# 19                                             11.788
# 20                                             16.200
# 21                                             17.750
# 22                                             18.036
# 23                                             18.343
# 24                                             17.817
# 25                                             15.871
# 26                                             15.563
# 27                                             15.090
# 28                                             17.817
# 29                                             17.817
# ..                                                ...
# 54                                             16.510
# 55                                             16.535
# 56                                             12.920
# 57                                             12.872
# 58                                             12.473
# 59                                             12.273
# 60                                             12.551
# 61                                             15.677
# 62                                             15.819
# 63                                             15.345
# 64                                             12.551
# 65                                             12.551
# 66                                             12.234
# 67                                             12.275
# 68                                             14.512
# 69                                             15.955
# 70                                             16.946
# 71                                             15.960
# 72                                             15.496
# 73                                             12.887
# 74                                             12.830
# 75                                             12.580
# 76                                             15.496
# 77                                             15.496
# 78                                             15.735
# 79                                             15.753
# 80                                             14.030
# 81                                             14.035
# 82                                             12.650
# 83                                             12.977
#
#     Mill use  (in  480-lb netweright in million bales)  Exports  \
# 0                                               4.170    11.550
# 1                                               3.370    10.000
# 2                                               3.370     9.950
# 3                                               3.370    10.425
# 4                                               3.870    11.100
# 5                                               3.720    11.650
# 6                                               3.620    12.225
# 7                                               3.520    12.300
# 8                                               3.470    10.300
# 9                                               3.470     9.700
# 10                                              3.470     9.700
# 11                                              3.470    10.000
# 12                                              3.370    10.400
# 13                                              3.570    15.025
# 14                                              3.420    15.275
# 15                                              3.520    15.275
# 16                                              3.370    11.400
# 17                                              3.470    11.375
# 18                                              3.470    11.365
# 19                                              3.375    11.340
# 20                                              3.275    13.050
# 21                                              3.370    13.800
# 22                                              3.370    14.525
# 23                                              3.570    15.025
# 24                                              3.565    15.280
# 25                                              3.775    10.825
# 26                                              3.775    10.625
# 27                                              3.575    10.650
# 28                                              3.565    15.280
# 29                                              3.565    15.280
# ..                                                ...       ...
# 54                                              3.380    12.225
# 55                                              3.380    12.450
# 56                                              3.475    10.350
# 57                                              3.475    10.350
# 58                                              3.480    13.380
# 59                                              3.480     9.650
# 60                                              3.580     9.750
# 61                                              3.775     9.450
# 62                                              3.775     9.450
# 63                                              3.775     9.450
# 64                                              3.580     9.750
# 65                                              3.580     9.950
# 66                                              3.580     9.975
# 67                                              3.580     9.675
# 68                                              3.675     9.220
# 69                                              3.775     9.720
# 70                                              3.775    10.150
# 71                                              3.775     9.450
# 72                                              3.775     9.450
# 73                                              3.675     9.700
# 74                                              3.675     9.700
# 75                                              3.675     9.500
# 76                                              3.625    10.200
# 77                                              3.625    10.250
# 78                                              3.625    10.250
# 79                                              3.625    10.300
# 80                                              3.775    10.150
# 81                                              3.725    10.250
# 82                                              3.675     9.475
# 83                                              3.675     9.700
#
#     MenClothing_Sales  OtherClothing_Sales  WomenClothing_Sales  \
# 0              524.00           936.000000            1755.0000
# 1              610.00           914.000000            2579.0000
# 2              620.00           955.000000            2521.0000
# 3              930.00          1351.000000            3390.0000
# 4              496.00           859.000000            1729.0000
# 5              542.00           921.000000            2256.0000
# 6              669.00           914.000000            2662.0000
# 7              650.00           989.000000            2732.0000
# 8              607.00           932.000000            2220.0000
# 9              575.00           901.000000            2164.0000
# 10             551.00           865.000000            2371.0000
# 11             579.00           819.000000            2421.0000
# 12             476.00           945.000000            2142.0000
# 13             634.00           930.000000            3071.0000
# 14             669.00          1035.000000            3276.0000
# 15             988.00          1398.000000            4360.0000
# 16             471.00           869.000000            2413.0000
# 17             568.00           941.000000            3102.0000
# 18             630.00          1143.506329            3409.8125
# 19             627.00           991.000000            3221.0000
# 20             598.00           984.000000            2756.0000
# 21             544.00           937.000000            2749.0000
# 22             678.95           897.000000            2807.0000
# 23             563.00           839.000000            2919.0000
# 24             487.00           968.000000            2193.0000
# 25             682.00          1020.000000            3409.8125
# 26             707.00          1147.000000            3499.0000
# 27            1081.00          1596.000000            4775.0000
# 28             497.00           878.000000            2620.0000
# 29             599.00          1064.000000            3266.0000
# ..                ...                  ...                  ...
# 54             718.00          1188.000000            3883.0000
# 55             749.00          1194.000000            4170.0000
# 56             678.00          1261.000000            3360.0000
# 57             648.00          1126.000000            3320.0000
# 58             687.00          1311.000000            3539.0000
# 59             681.00          1043.000000            3720.0000
# 60             573.00          1172.000000            2961.0000
# 61             757.00          1153.000000            4434.0000
# 62             803.00          1468.000000            4525.0000
# 63            1070.00          1967.000000            5664.0000
# 64             636.00          1123.000000            3381.0000
# 65             702.00          1293.000000            4268.0000
# 66             785.00          1196.000000            4223.0000
# 67             801.00          1257.000000            4421.0000
# 68             702.00          1143.506329            3905.0000
# 69             655.00          1175.000000            3733.0000
# 70             692.00          1337.000000            4067.0000
# 71             678.95          1056.000000            4481.0000
# 72             560.00          1190.000000            3041.0000
# 73             800.00          1283.000000            4372.0000
# 74             643.00          1478.000000            4401.0000
# 75             967.00          1680.000000            5874.0000
# 76             602.00          1210.000000            3646.0000
# 77             645.00          1300.000000            4294.0000
# 78             701.00          1205.000000            3409.8125
# 79             800.00          1363.000000            4413.0000
# 80             716.00          1402.000000            3899.0000
# 81             661.00          1349.000000            3817.0000
# 82             712.00          1405.000000            3897.0000
# 83             690.00          1261.000000            3881.0000
#
#     Sales(In ThousandDollars)
# 0                 3215.000000
# 1                 4103.000000
# 2                 4096.000000
# 3                 5671.000000
# 4                 3084.000000
# 5                 3719.000000
# 6                 4245.000000
# 7                 4371.000000
# 8                 3759.000000
# 9                 3640.000000
# 10                3787.000000
# 11                3819.000000
# 12                3563.000000
# 13                4635.000000
# 14                4980.000000
# 15                6746.000000
# 16                3753.000000
# 17                4611.000000
# 18                5183.318829
# 19                4839.000000
# 20                4338.000000
# 21                4230.000000
# 22                4382.950000
# 23                4321.000000
# 24                3648.000000
# 25                5111.812500
# 26                5353.000000
# 27                7452.000000
# 28                3995.000000
# 29                4929.000000
# ..                        ...
# 54                5789.000000
# 55                6113.000000
# 56                5299.000000
# 57                5094.000000
# 58                5537.000000
# 59                5444.000000
# 60                4706.000000
# 61                6344.000000
# 62                6796.000000
# 63                8701.000000
# 64                5140.000000
# 65                6263.000000
# 66                6204.000000
# 67                6479.000000
# 68                5750.506329
# 69                5563.000000
# 70                6096.000000
# 71                6215.950000
# 72                4791.000000
# 73                6455.000000
# 74                6522.000000
# 75                8521.000000
# 76                5458.000000
# 77                6239.000000
# 78                5315.812500
# 79                6576.000000
# 80                6017.000000
# 81                5827.000000
# 82                6014.000000
# 83                5832.000000
#
# [84 rows x 44 columns]

# %%
trainingDataFull.isnull().sum()
# Out:
# Year                                                                  0
# Month                                                                 0
# Temp high (°C)                                                        0
# Temp avg (°C)                                                         0
# Temp low (°C)                                                         0
# Dew Point high (°C)                                                   0
# Dew Point avg (°C)                                                    0
# Dew Point low (°C)                                                    0
# Humidity_high                                                         0
# Humidity_avg                                                          0
# Humidity_low                                                          0
# Sea Level Press high                                                  0
# Sea Level Press avg                                                   0
# Sea Level Press low                                                   0
# Visibility (km) high                                                  0
# Visibility (km) avg                                                   0
# Visibility (km) low                                                   0
# Wind (km/h) low                                                       0
# Wind (km/h) avg                                                       0
# Wind (km/h) high                                                      0
# Precip (mm) sum                                                       0
# Event                                                                14
# Federal Holiday                                                      14
# Event_Yes_No                                                         14
# Federal Holiday_Yes_No                                               14
# Monthly Nominal GDP Index (inMillion$)                                0
# Monthly Real GDP Index (inMillion$)                                   0
# CPI                                                                   0
# unemployment rate                                                     0
# CommercialBankInterestRateonCreditCardPlans                           0
# Finance Rate on Personal Loans at Commercial Banks, 24 Month Loan     0
# Earnings or wages  in dollars per hour                                0
# Cotton Monthly Price - US cents per Pound(lbs)                        0
# Change(in%)                                                           0
# Average upland planted(million acres)                                 0
# Average upland harvested(million acres)                               0
# yieldperharvested acre                                                0
# Production (in  480-lb netweright in million bales)                   0
# Mill use  (in  480-lb netweright in million bales)                    0
# Exports                                                               0
# MenClothing_Sales                                                     0
# OtherClothing_Sales                                                   0
# WomenClothing_Sales                                                   0
# Sales(In ThousandDollars)                                             0
# dtype: int64

# %% [markdown]
# ## Visual Expploratory Data Analysis On "trainDataFull" ( Fully Merged Data )

# %% [markdown]
# ## Correlation Of All Variables With Target Variable

# %%
corr = trainingDataFull.corr()
corr.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col0 {
#             background-color:  #023858;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col1 {
#             background-color:  #c2cbe2;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col2 {
#             background-color:  #84b0d3;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col3 {
#             background-color:  #86b0d3;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col4 {
#             background-color:  #84b0d3;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col5 {
#             background-color:  #8bb2d4;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col6 {
#             background-color:  #8eb3d5;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col7 {
#             background-color:  #8fb4d6;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col8 {
#             background-color:  #e0deed;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col9 {
#             background-color:  #e5e1ef;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col10 {
#             background-color:  #eae6f1;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col11 {
#             background-color:  #63a2cb;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col12 {
#             background-color:  #71a8ce;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col13 {
#             background-color:  #6ba5cd;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col14 {
#             background-color:  #e3e0ee;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col15 {
#             background-color:  #b3c3de;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col16 {
#             background-color:  #bcc7e1;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col17 {
#             background-color:  #b8c6e0;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col18 {
#             background-color:  #bcc7e1;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col19 {
#             background-color:  #79abd0;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col20 {
#             background-color:  #cccfe5;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col21 {
#             background-color:  #b3c3de;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col22 {
#             background-color:  #d3d4e7;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col23 {
#             background-color:  #02395a;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col24 {
#             background-color:  #023a5b;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col25 {
#             background-color:  #023c5f;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col26 {
#             background-color:  #fef6fa;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col27 {
#             background-color:  #faf3f9;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col28 {
#             background-color:  #fff7fb;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col29 {
#             background-color:  #02395a;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col30 {
#             background-color:  #f2ecf5;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col31 {
#             background-color:  #f3edf5;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col32 {
#             background-color:  #c6cce3;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col33 {
#             background-color:  #eee8f3;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col34 {
#             background-color:  #e6e2ef;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col35 {
#             background-color:  #eee9f3;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col36 {
#             background-color:  #7dacd1;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col37 {
#             background-color:  #fdf5fa;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col38 {
#             background-color:  #75a9cf;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col39 {
#             background-color:  #0569a4;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col40 {
#             background-color:  #0567a1;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row0_col41 {
#             background-color:  #0569a4;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row1_col0 {
#             background-color:  #79abd0;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row1_col1 {
#             background-color:  #023858;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row1_col2 {
#             background-color:  #3991c1;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row1_col3 {
#             background-color:  #308cbe;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row1_col4 {
#             background-color:  #2987bc;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row1_col5 {
#             background-color:  #2484ba;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row1_col6 {
#             background-color:  #2383ba;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row1_col7 {
#             background-color:  #2182b9;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row1_col8 {
#             background-color:  #4e9ac6;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row1_col9 {
#             background-color:  #3f93c2;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row1_col10 {
#             background-color:  #4094c3;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row1_col11 {
#             background-color:  #a2bcda;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row1_col12 {
#             background-color:  #96b6d7;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row1_col13 {
#             background-color:  #71a8ce;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row1_col14 {
#             background-color:  #d6d6e9;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row1_col15 {
#             background-color:  #81aed2;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row1_col16 {
#             background-color:  #8cb3d5;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row1_col17 {
#             background-color:  #d5d5e8;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row1_col18 {
#             background-color:  #ced0e6;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row1_col19 {
#             background-color:  #d1d2e6;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row1_col20 {
#             background-color:  #a8bedc;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row1_col21 {
#             background-color:  #97b7d7;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row1_col22 {
#             background-color:  #a1bbda;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row1_col23 {
#             background-color:  #569dc8;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row1_col24 {
#             background-color:  #549cc7;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row1_col25 {
#             background-color:  #65a3cb;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row1_col26 {
#             background-color:  #86b0d3;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row1_col27 {
#             background-color:  #93b5d6;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row1_col28 {
#             background-color:  #9ab8d8;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row1_col29 {
#             background-color:  #65a3cb;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row1_col30 {
#             background-color:  #ece7f2;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row1_col31 {
#             background-color:  #dbdaeb;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row1_col32 {
#             background-color:  #d6d6e9;
#         }    #T_fda161f4_2b00_11e9_ba8e_fc15b4e90c00row1_col33 {
#             background-color:  #dcdaeb;
#         }    #T_fda161f

# %% [markdown]
# ### Top 4 Correlations Of "Sales(In ThousandDollars)"

# %%
corr_Sales = corr[['Sales(In ThousandDollars)']].sort_values('Sales(In ThousandDollars)', ascending=False).reset_index()
corr_Sales.head(10)
# Out:
#                                     index  Sales(In ThousandDollars)
# 0               Sales(In ThousandDollars)                   1.000000
# 1                     WomenClothing_Sales                   0.990436
# 2                     OtherClothing_Sales                   0.904553
# 3                       MenClothing_Sales                   0.864588
# 4  Monthly Nominal GDP Index (inMillion$)                   0.711630
# 5     Monthly Real GDP Index (inMillion$)                   0.710515
# 6  Earnings or wages  in dollars per hour                   0.694507
# 7                                     CPI                   0.683552
# 8                                    Year                   0.653597
# 9                                   Event                   0.539977

# %%
plt.subplots(figsize = (12, 6))
sns.scatterplot(x='Monthly Real GDP Index (inMillion$)', size='Monthly Nominal GDP Index (inMillion$)', 
                y='Sales(In ThousandDollars)', hue='CPI', data = trainingDataFull)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('Real GDP vs Nominal GDP vs CPI vs Sales Correlation')
plt.show()

# %% [markdown]
# ### Correlations Of All Variables With Sales(In ThousandDollars)

# %%
plt.subplots(figsize = (25, 10))
g = sns.barplot(x='index', y='Sales(In ThousandDollars)', data = corr_Sales)
g.set_xticklabels(g.get_xticklabels(), rotation=90)
plt.show()

# %% [markdown]
# ### Top 4 Correlations Of "MenClothing_Sales"

# %%
corr_men = corr[['MenClothing_Sales']].sort_values('MenClothing_Sales', ascending=False).reset_index()
corr_men.head(10)
# Out:
#                                     index  MenClothing_Sales
# 0                       MenClothing_Sales           1.000000
# 1               Sales(In ThousandDollars)           0.864588
# 2                     WomenClothing_Sales           0.813786
# 3                     OtherClothing_Sales           0.787831
# 4                                   Event           0.650091
# 5                                   Month           0.636741
# 6  Monthly Nominal GDP Index (inMillion$)           0.394155
# 7     Monthly Real GDP Index (inMillion$)           0.390096
# 8                                     CPI           0.382205
# 9  Earnings or wages  in dollars per hour           0.374101

# %%
plt.subplots(figsize = (12, 6))
sns.scatterplot(x='Month',size='Monthly Nominal GDP Index (inMillion$)',
                y='MenClothing_Sales', hue = 'Event', data = trainingDataFull)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('Month vs Nominal GDP vs Event vs MenClothing Correlation')
plt.show()

# %% [markdown]
# ### Top 4 Correlations Of "WomenClothing_Sales"

# %%
corr_men = corr[['WomenClothing_Sales']].sort_values('WomenClothing_Sales', ascending=False).reset_index()
corr_men.head(10)
# Out:
#                                     index  WomenClothing_Sales
# 0                     WomenClothing_Sales             1.000000
# 1               Sales(In ThousandDollars)             0.990436
# 2                     OtherClothing_Sales             0.848495
# 3                       MenClothing_Sales             0.813786
# 4  Monthly Nominal GDP Index (inMillion$)             0.727154
# 5     Monthly Real GDP Index (inMillion$)             0.726710
# 6  Earnings or wages  in dollars per hour             0.709473
# 7                                     CPI             0.703465
# 8                                    Year             0.671591
# 9                                   Event             0.498258

# %%
plt.subplots(figsize = (12, 6))
sns.scatterplot(x='Monthly Real GDP Index (inMillion$)', size='Monthly Nominal GDP Index (inMillion$)', 
                y='WomenClothing_Sales', hue='CPI', data = trainingDataFull)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('Real GDP vs Nominal GDP vs CPI vs WomenClothing Correlation')
plt.show()

# %% [markdown]
# ### Top 4Correlations Of "OtherClothing_Sales"

# %%
corr_others = corr[['OtherClothing_Sales']].sort_values('OtherClothing_Sales', ascending=False).reset_index() 
corr_others.head(10)
# Out:
#                                     index  OtherClothing_Sales
# 0                     OtherClothing_Sales             1.000000
# 1               Sales(In ThousandDollars)             0.904553
# 2                     WomenClothing_Sales             0.848495
# 3                       MenClothing_Sales             0.787831
# 4  Monthly Nominal GDP Index (inMillion$)             0.697020
# 5     Monthly Real GDP Index (inMillion$)             0.695396
# 6  Earnings or wages  in dollars per hour             0.687695
# 7                                    Year             0.655252
# 8                                     CPI             0.647660
# 9                                   Event             0.518436

# %%
plt.subplots(figsize = (12, 6))
sns.scatterplot(x='Monthly Real GDP Index (inMillion$)', size='Monthly Nominal GDP Index (inMillion$)', 
                y='OtherClothing_Sales', hue='CPI', data = trainingDataFull)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('Real GDP vs Nominal GDP vs CPI vs OtherClothing Correlation')
plt.show()

# %%
plt.subplots(figsize = (25, 10))
g = sns.barplot(x='index', y='Sales(In ThousandDollars)', data = corr_Sales)
g.set_xticklabels(g.get_xticklabels(), rotation=90)
plt.show()

# %% [markdown]
# ## Bivariate Correlation Plots

# %%
from numpy.polynomial.polynomial import polyfit

plt.subplots(figsize=(10, 4))
x = trainingDataFull['unemployment rate']
y = trainingDataFull['Sales(In ThousandDollars)']

b, m = polyfit(x, y, 1)
plt.plot(x, y, '.')
plt.plot(x, b + m * x, '-')

plt.legend([x.corr(y)])
plt.title('UnemploymentRate vs Sales')
plt.xlabel('unemployment rate')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# ### Exports vs Sales

# %%
from numpy.polynomial.polynomial import polyfit

plt.subplots(figsize=(10, 4))
x = trainingDataFull['Exports']
y = trainingDataFull['Sales(In ThousandDollars)']

b, m = polyfit(x, y, 1)
plt.plot(x, y, '.')
plt.plot(x, b + m * x, '-')

plt.legend([x.corr(y)])
plt.title('Exports vs Sales')
plt.xlabel('unemployment rate')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# ### Interest Rates vs Sales

# %%
fig, ((ax1, ax2)) = plt.subplots(nrows=1, ncols=2, figsize = (20,6))
#fig.autofmt_xdate(rotation = 45)
x1 = trainingDataFull['CommercialBankInterestRateonCreditCardPlans']
x2 = trainingDataFull['Finance Rate on Personal Loans at Commercial Banks, 24 Month Loan']
y = trainingDataFull['Sales(In ThousandDollars)'] 

b, m = polyfit(x1, y, 1)
ax1.plot(x1, y, '.')
ax1.plot(x1, b + m * x1, '-')
ax1.legend([x1.corr(y)])

b1, m1 = polyfit(x2, y, 1)
ax2.plot(x2, y, '.')
ax2.plot(x2, b1 + m1 * x2, '-')
ax2.legend([x2.corr(y)])

ax1.scatter(x1, y)
ax1.set_xlabel('Credit Card Interest Rate'); ax1.set_ylabel('Sales'); ax1.set_title('Credit Card Interest Rate vs Sales')
ax2.scatter(x2, y)
ax2.set_xlabel('Personal Loan Interest Rate'); ax2.set_ylabel('Sales'); ax2.set_title('Personal Loan Interest Rate vs Sales')

plt.show()
